# %% [markdown]
# Autores do Notebook:
#
# - Otávio Kamel
# - Wesley Souza

# %% [markdown]
# To Do:
# - ajeitar as informaçãos a mais de KNN
# - colocar uma tabela para comparar facilmente os resultados dos modelos
# - ajeitar início da seção 7

# %% [markdown]
# Observação!
#
# ![image.png](attachment:9ffe3b9a-7c88-4808-accd-26335562a843.png)

# %% [markdown]
# # 0. Import & Settings

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scikitplot as skplt


from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.model_selection import cross_val_score, cross_validate, GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from boruta import BorutaPy
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score, make_scorer, accuracy_score
from sklearn.model_selection import cross_validate, cross_val_score, cross_val_predict, StratifiedKFold
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
#from yellowbrick.classifier import ROCAUC

# %%
sns.set_style('darkgrid')

pd.set_option('max_columns', 100)
pd.set_option('max_rows', 50)
pd.set_option('min_rows', 20)
pd.set_option('precision', 2) 
pd.options.display.float_format = '{:.2f}'.format

# %%
# %matplotlib inline

# %pylab inline

plt.style.use( 'bmh' )
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['font.size'] = 24

#pd.options.display.max_columns = None
#pd.options.display.max_rows = None
pd.set_option('display.expand_frame_repr', False)

sns.set()

sns.set_style('whitegrid')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 1. Data Description

# %%
df1 = pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')

# %%
df1.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS           NObeyesdad
# 0  Female 21.00    1.62   64.00                            yes   no  2.00 3.00  Sometimes    no  2.00   no 0.00 1.00          no  Public_Transportation        Normal_Weight
# 1  Female 21.00    1.52   56.00                            yes   no  3.00 3.00  Sometimes   yes  3.00  yes 3.00 0.00   Sometimes  Public_Transportation        Normal_Weight
# 2    Male 23.00    1.80   77.00                            yes   no  2.00 3.00  Sometimes    no  2.00   no 2.00 1.00  Frequently  Public_Transportation        Normal_Weight
# 3    Male 27.00    1.80   87.00                             no   no  3.00 3.00  Sometimes    no  2.00   no 2.00 0.00  Frequently                Walking   Overweight_Level_I
# 4    Male 22.00    1.78   89.80                             no   no  2.00 1.00  Sometimes    no  2.00   no 0.00 0.00   Sometimes  Public_Transportation  Overweight_Level_II

# %%
print(f'O dataset possui {df1.shape[0]} linhas e {df1.shape[1]} colunas')
# Out:
# O dataset possui 2111 linhas e 17 colunas

# %%
df1.describe()
# Out:
#           Age  Height  Weight    FCVC     NCP    CH2O     FAF     TUE
# count 2111.00 2111.00 2111.00 2111.00 2111.00 2111.00 2111.00 2111.00
# mean    24.31    1.70   86.59    2.42    2.69    2.01    1.01    0.66
# std      6.35    0.09   26.19    0.53    0.78    0.61    0.85    0.61
# min     14.00    1.45   39.00    1.00    1.00    1.00    0.00    0.00
# 25%     19.95    1.63   65.47    2.00    2.66    1.58    0.12    0.00
# 50%     22.78    1.70   83.00    2.39    3.00    2.00    1.00    0.63
# 75%     26.00    1.77  107.43    3.00    3.00    2.48    1.67    1.00
# max     61.00    1.98  173.00    3.00    4.00    3.00    3.00    2.00

# %%
df1.isna().sum().sum()
# Out:
# 0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
#  12  FAF                             2111 non-null   float64
#  13  TUE                             2111 non-null   float64
#  14  CALC                            2111 non-null   object
#  15  MTRANS                          2111 non-null   object
#  16  NObeyesdad                      2111 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 280.5+ KB

# %%
df1.dtypes
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
df1.dtypes.value_counts()
# Out:
# object     9
# float64    8
# dtype: int64

# %%
num_attr = df1.select_dtypes(exclude='object')
cat_attr = df1.select_dtypes(include='object')

# %%
sns.countplot(x=df1['NObeyesdad']);

# %%
df1.hist();

# %%
# Verificando correlação entre as características
corr_input_var = num_attr.corr()

fig, ax = plt.subplots(figsize=(12,9))
sns.heatmap(corr_input_var, annot=True, cbar=False, cmap='Reds', linewidths=.5, ax=ax);

# %%
df1.describe(include='object')
# Out:
#        Gender family_history_with_overweight  FAVC       CAEC SMOKE   SCC       CALC                 MTRANS      NObeyesdad
# count    2111                           2111  2111       2111  2111  2111       2111                   2111            2111
# unique      2                              2     2          4     2     2          4                      5               7
# top      Male                            yes   yes  Sometimes    no    no  Sometimes  Public_Transportation  Obesity_Type_I
# freq     1068                           1726  1866       1765  2067  2015       1401                   1580             351

# %%
for column in df1.select_dtypes(include='object'):
    if df1[column].nunique() < 10:
        sns.countplot(x=column, data=df1)
        plt.show()

# %%
### Verificando frequência relativa entre atributos categóricos com menos de 5 valores distintos
for col in df1.drop('NObeyesdad', axis=1).select_dtypes(include='object'):
    if df1[col].nunique() <=4:
        display(pd.crosstab(df1['NObeyesdad'], df1[col], normalize='index'))
# Out:
# Gender               Female  Male
# NObeyesdad
# Insufficient_Weight    0.64  0.36
# Normal_Weight          0.49  0.51
# Obesity_Type_I         0.44  0.56
# Obesity_Type_II        0.01  0.99
# Obesity_Type_III       1.00  0.00
# Overweight_Level_I     0.50  0.50
# Overweight_Level_II    0.36  0.64
# family_history_with_overweight   no  yes
# NObeyesdad
# Insufficient_Weight            0.54 0.46
# Normal_Weight                  0.46 0.54
# Obesity_Type_I                 0.02 0.98
# Obesity_Type_II                0.00 1.00
# Obesity_Type_III               0.00 1.00
# Overweight_Level_I             0.28 0.72
# Overweight_Level_II            0.06 0.94
# FAVC                  no  yes
# NObeyesdad
# Insufficient_Weight 0.19 0.81
# Normal_Weight       0.28 0.72
# Obesity_Type_I      0.03 0.97
# Obesity_Type_II     0.02 0.98
# Obesity_Type_III    0.00 1.00
# Overweight_Level_I  0.08 0.92
# Overweight_Level_II 0.26 0.74
# CAEC                 Always  Frequently  Sometimes   no
# NObeyesdad
# Insufficient_Weight    0.01        0.44       0.54 0.01
# Normal_Weight          0.12        0.29       0.55 0.03
# Obesity_Type_I         0.02        0.02       0.96 0.00
# Obesity_Type_II        0.01        0.00       0.99 0.00
# Obesity_Type_III       0.00        0.00       1.00 0.00
# Overweight_Level_I     0.02        0.05       0.81 0.12
# Overweight_Level_II    0.01        0.06       0.93 0.00
# SMOKE                 no  yes
# NObeyesdad
# Insufficient_Weight 1.00 0.00
# Normal_Weight       0.95 0.05
# Obesity_Type_I      0.98 0.02
# Obesity_Type_II     0.95 0.05
# Obesity_Type_III    1.00 0.00
# Overweight_Level_I  0.99 0.01
# Overweight_Level_II 0.98 0.02
# SCC                   no  yes
# NObeyesdad
# Insufficient_Weight 0.92 0.08
# Normal_Weight       0.90 0.10
# Obesity_Type_I      0.99 0.01
# Obesity_Type_II     1.00 0.00
# Obesity_Type_III    1.00 0.00
# Overweight_Level_I  0.87 0.13
# Overweight_Level_II 0.99 0.01
# CALC                 Always  Frequently  Sometimes   no
# NObeyesdad
# Insufficient_Weight    0.00        0.00       0.57 0.43
# Normal_Weight          0.00        0.06       0.56 0.37
# Obesity_Type_I         0.00        0.04       0.49 0.47
# Obesity_Type_II        0.00        0.01       0.75 0.24
# Obesity_Type_III       0.00        0.00       1.00 0.00
# Overweight_Level_I     0.00        0.06       0.77 0.17
# Overweight_Level_II    0.00        0.07       0.49 0.44

# %% [markdown]
# # 2.0 Exploratory Data Analysis

# %%
df_temporario = df1[['Weight', 'NObeyesdad']].groupby('NObeyesdad').mean().reset_index()
ax = sns.barplot(data=df_temporario, x='NObeyesdad', y='Weight');

# código para mostrar os valores das colunas no gráfico
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
       ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

# %%
df_temporario = df1[['Height', 'NObeyesdad']].groupby('NObeyesdad').mean().reset_index()
ax = sns.barplot(data=df_temporario, x='NObeyesdad', y='Height');

# código para mostrar os valores das colunas no gráfico
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
       ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

# %%
df_temporario = df1[['Age', 'NObeyesdad']].groupby('NObeyesdad').mean().reset_index()
ax = sns.barplot(data=df_temporario, x='NObeyesdad', y='Age');

# código para mostrar os valores das colunas no gráfico
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
       ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

# %% [markdown]
# # 3. Pre-Processing

# %%
df2 = df1.copy()

# %% [markdown]
# ## 3.1 Scaling

# %%
num_attr.columns
# Out:
# Index(['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE'], dtype='object')

# %%
# Checando Outliers para escolher RobustScaler ou MinMaxScaler

# %%
sns.boxplot(x = df2['Age']);

# %%
sns.boxplot(x = df2['Height']);

# %%
sns.boxplot(x = df2['Weight']);

# %%
sns.boxplot(x = df2['FCVC']);

# %%
sns.boxplot(x = df2['NCP']);

# %%
sns.boxplot(x = df2['CH2O']);

# %%
sns.boxplot(x = df2['FAF']);

# %%
sns.boxplot(x = df2['TUE']);

# %%
rs = RobustScaler()
mms = MinMaxScaler()

df2['Age'] = rs.fit_transform(df2[['Age']])

# o robust scaler "piorou" a escala
#df2['NCP'] = rs.fit_transform(df2[['NCP']])

df2['Height'] = mms.fit_transform(df2[['Height']])

df2['Weight'] = mms.fit_transform(df2[['Weight']])

df2['FCVC'] = mms.fit_transform(df2[['FCVC']])

df2['CH2O'] = mms.fit_transform(df2[['CH2O']])

df2['FAF'] = mms.fit_transform(df2[['FAF']])

df2['TUE'] = mms.fit_transform(df2[['TUE']])

# %%
df2.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS           NObeyesdad
# 0  Female -0.29    0.32    0.19                            yes   no  0.50 3.00  Sometimes    no  0.50   no 0.00 0.50          no  Public_Transportation        Normal_Weight
# 1  Female -0.29    0.13    0.13                            yes   no  1.00 3.00  Sometimes   yes  1.00  yes 1.00 0.00   Sometimes  Public_Transportation        Normal_Weight
# 2    Male  0.04    0.66    0.28                            yes   no  0.50 3.00  Sometimes    no  0.50   no 0.67 0.50  Frequently  Public_Transportation        Normal_Weight
# 3    Male  0.70    0.66    0.36                             no   no  1.00 3.00  Sometimes    no  0.50   no 0.67 0.00  Frequently                Walking   Overweight_Level_I
# 4    Male -0.13    0.62    0.38                             no   no  0.50 1.00  Sometimes    no  0.50   no 0.00 0.00   Sometimes  Public_Transportation  Overweight_Level_II

# %% [markdown]
# ## 3.2 Encoding

# %%
cat_attr.columns
# Out:
# Index(['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE',
#        'SCC', 'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
cat_attr.nunique()
# Out:
# Gender                            2
# family_history_with_overweight    2
# FAVC                              2
# CAEC                              4
# SMOKE                             2
# SCC                               2
# CALC                              4
# MTRANS                            5
# NObeyesdad                        7
# dtype: int64

# %%
df2['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
temp_dict = {'Female': 1, 'Male': 0}
df2['Gender'] = df2['Gender'].map(temp_dict)

# %%
df2['family_history_with_overweight'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
temp_dict = {'yes': 1, 'no': 0}
df2['family_history_with_overweight'] = df2['family_history_with_overweight'].map(temp_dict)

# %%
df2['FAVC'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
temp_dict = {'yes': 1, 'no': 0}
df2['FAVC'] = df2['FAVC'].map(temp_dict)

# %%
df2['CAEC'].unique()
# Out:
# array(['Sometimes', 'Frequently', 'Always', 'no'], dtype=object)

# %%
ordinal_encoding = {'no': 0, 'Sometimes': 1, 'Frequently': 2, 'Always': 3}
df2['CAEC'] = df2['CAEC'].map(ordinal_encoding)

# %%
df2['SMOKE'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
temp_dict = {'yes': 1, 'no': 0}
df2['SMOKE'] = df2['SMOKE'].map(temp_dict)

# %%
df2['SCC'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
temp_dict = {'yes': 1, 'no': 0}
df2['SCC'] = df2['SCC'].map(temp_dict)

# %%
df2['CALC'].unique()
# Out:
# array(['no', 'Sometimes', 'Frequently', 'Always'], dtype=object)

# %%
ordinal_encoding = {'no': 0, 'Sometimes': 1, 'Frequently': 2, 'Always': 3}
df2['CALC'] = df2['CALC'].map(ordinal_encoding)

# %%
df2['MTRANS'].unique()
# Out:
# array(['Public_Transportation', 'Walking', 'Automobile', 'Motorbike',
#        'Bike'], dtype=object)

# %%
frequency_encoder = df2.groupby('MTRANS').size()/len(df1)
df2.loc[:, 'MTRANS'] = df2['MTRANS'].map(frequency_encoder)

# %%
df2['NObeyesdad'].unique()
# Out:
# array(['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II',
#        'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II',
#        'Obesity_Type_III'], dtype=object)

# %%
temp_dict = {'Insufficient_Weight' : 0, 'Normal_Weight': 1, 'Overweight_Level_I': 2, 'Overweight_Level_II': 3, 'Obesity_Type_I': 4, 'Obesity_Type_II': 5, 'Obesity_Type_III': 6}
df2['target'] = df2['NObeyesdad'].map(temp_dict)

# %%
df2.sample(5)
# Out:
#       Gender   Age  Height  Weight  family_history_with_overweight  FAVC  FCVC  NCP  CAEC  SMOKE  CH2O  SCC  FAF  TUE  CALC  MTRANS           NObeyesdad  target
# 1149       0 -0.84    0.50    0.33                               1     1  0.50 2.72     1      0  0.33    0 0.33 0.30     1    0.75  Overweight_Level_II       3
# 775        0 -0.77    0.62    0.31                               1     1  0.29 3.00     1      0  0.50    0 0.90 0.00     0    0.75   Overweight_Level_I       2
# 1538       0  0.98    0.41    0.45                               1     1  0.98 2.83     1      0  0.00    0 0.67 0.00     0    0.75      Obesity_Type_II       5
# 267        0  2.51    0.47    0.29                               0     1  1.00 3.00     2      0  0.50    0 0.00 0.00     2    0.22  Overweight_Level_II       3
# 2078       1 -0.27    0.55    0.83                               1     1  1.00 3.00     1      0  0.66    0 0.53 0.34     1    0.75     Obesity_Type_III       6

# %% [markdown]
# # 4.0 Feature Selection

# %% [markdown]
# ## 4.1 Split Dataframe into Training Validation and Test Dataset

# %%
x_full, x_test, y_full, y_test = train_test_split(df2.drop(['NObeyesdad', 'target'], axis=1), df2['target'], random_state = 16, train_size=0.90)

print('\nTamanho treino: {}'.format(x_full.shape[0]))
print('Tamanho teste: {}'.format(x_test.shape[0]))
# Out:
# Tamanho treino: 1899
# Tamanho teste: 212

# %%
X_train, X_val, y_train, y_val = train_test_split(x_full, y_full, random_state = 16, train_size=0.80)

print('\nTamanho treino: {}'.format(X_train.shape[0]))
print('Tamanho validação: {}'.format(X_val.shape[0]))
# Out:
# Tamanho treino: 1519
# Tamanho validação: 380

# %% [markdown]
# ## 4.2 Boruta as Feature Selector

# %%
# training and test dataset for Boruta
X_train_n = X_train.values
y_train_n = y_train.values.ravel()

# %%
# define RandomForestClassifier
rf = RandomForestClassifier(n_jobs=-2)

# define Boruta
boruta = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=42).fit(X_train_n, y_train_n)
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	16
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	16
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	16
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	16
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	16
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	16
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	16
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	12
# Tentative: 	0
# Rejected: 	4
#
#
# BorutaPy finished running.
#
# Iteration: 	9 / 100
# Confirmed: 	12
# Tentative: 	0
# Rejected: 	4

# %%
cols_selected = boruta.support_.tolist()

# best features
X_train_fs = X_train
cols_selected_boruta = X_train_fs.iloc[:, cols_selected].columns.to_list()

# not selected boruta
cols_not_selected_boruta = list(np.setdiff1d(X_train_fs.columns, cols_selected_boruta))

# %%
cols_selected_boruta
# Out:
# ['Gender',
#  'Age',
#  'Height',
#  'Weight',
#  'family_history_with_overweight',
#  'FCVC',
#  'NCP',
#  'CAEC',
#  'CH2O',
#  'FAF',
#  'TUE',
#  'CALC']

# %%
cols_not_selected_boruta
# Out:
# ['FAVC', 'MTRANS', 'SCC', 'SMOKE']

# %% [markdown]
# ## 4.2 Feature Selection Using Random Forest Classifier

# %%
# model
rf = RandomForestClassifier(n_estimators=100, n_jobs=-5, random_state=42 ).fit(X_train_n, y_train_n)

# %%
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance', ascending=False)
feature_importances
# Out:
#                                 importance
# Weight                                0.35
# Height                                0.10
# Age                                   0.10
# FCVC                                  0.08
# Gender                                0.05
# NCP                                   0.05
# CH2O                                  0.04
# FAF                                   0.04
# TUE                                   0.04
# CAEC                                  0.03
# family_history_with_overweight        0.03
# CALC                                  0.03
# MTRANS                                0.02
# FAVC                                  0.02
# SCC                                   0.01
# SMOKE                                 0.00

# %%
pd.Series(rf.feature_importances_, index=X_train.columns).plot(kind='barh');

# %%
pd.Series(rf.feature_importances_, index=X_train.columns).nlargest(len(X_train.columns)).plot(kind='barh');

# %%
feat_importances = pd.Series(rf.feature_importances_, index=X_train.columns)
feat_importances.nlargest(8).plot(kind='barh');

# %% [markdown]
# ## 4.3 Feature Selection Using Extra-Trees Classifier

# %%
et = ExtraTreesClassifier(n_jobs=-5)
et.fit(X_train_n, y_train_n)

feature_importances = pd.DataFrame(et.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance', ascending=False)
feature_importances
# Out:
#                                 importance
# Weight                                0.27
# Age                                   0.08
# Height                                0.08
# Gender                                0.08
# FCVC                                  0.07
# NCP                                   0.06
# CALC                                  0.05
# family_history_with_overweight        0.05
# TUE                                   0.05
# FAF                                   0.05
# CH2O                                  0.04
# MTRANS                                0.04
# CAEC                                  0.04
# FAVC                                  0.03
# SCC                                   0.01
# SMOKE                                 0.00

# %%
feat_importances = pd.Series(et.feature_importances_, X_train.columns)
feat_importances.nlargest(17).plot(kind='barh');

# %% [markdown]
# ## 4.4 Manual Feature Selection

# %%
cols_selected = ['Gender',
 'Age',
 'Height',
 'Weight',
 'family_history_with_overweight',
 'FCVC',
 'NCP',
 'CAEC',
 'CH2O',
 'FAF',
 'TUE',
 'CALC',
 'MTRANS',
 'FAVC']

target = df2['target']

# %% [markdown]
# # 5.0 Machine Learning Modelling

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=16)

def stratified_kfold_evaluation(skf, model, x, y):
    lst_accu_stratified = []

    for train_index, val_index in skf.split(x, y):
        model.fit(x.iloc[train_index], y.iloc[train_index])
        lst_accu_stratified.append(model.score(x.iloc[val_index], y.iloc[val_index]))
        y_pred = model.predict(x.iloc[val_index])
        print(classification_report(y.iloc[val_index], y_pred))

    # Print the output.
    print('List of possible accuracy:', lst_accu_stratified)
    print('\nMaximum Accuracy That can be obtained from this model is:',
          max(lst_accu_stratified)*100, '%')
    print('\nMinimum Accuracy:',
          min(lst_accu_stratified)*100, '%')
    print('\nOverall Accuracy:',
          mean(lst_accu_stratified)*100, '%')
    print('\nStandard Deviation:', np.std(lst_accu_stratified)*100, '%')

# %%
def classification_report_with_accuracy_score(y_true, y_pred):
  print(classification_report(y_true, y_pred))
  return accuracy_score(y_true, y_true)

# %%
#     metrics = np.array(metrics)
#     print(f'Métrica média: {metrics.mean()}, desvio padrão: {metrics.std()}')
    
# kfold_trainning(KFold(n_splits=10))

# %%
# kf = KFold(n_splits=10, shuffle=True, random_state=16)

# for train_index, test_index in kf.split(10):
#     print("TRAIN:", train_index, "TEST:", test_index)
#     X_train, X_test = X[train_index], X[test_index]
#     y_train, y_test = y[train_index], y[test_index]

# %% [markdown]
# ## 5.1 Dummy Model

# %%
# Dummy model para servir de baseline

dummy_pred = randint(0, 6, size=y_val.shape)
classification_report_with_accuracy_score(y_val, dummy_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.11      0.15      0.12        46
#            1       0.13      0.17      0.15        46
#            2       0.14      0.19      0.16        53
#            3       0.13      0.20      0.16        51
#            4       0.08      0.06      0.07        62
#            5       0.07      0.07      0.07        58
#            6       0.00      0.00      0.00        64
#
#     accuracy                           0.11       380
#    macro avg       0.09      0.12      0.11       380
# weighted avg       0.09      0.11      0.10       380
# C:\Users\Kamel\.conda\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Kamel\.conda\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Kamel\.conda\envs\tf-gpu\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 1.0

# %% [markdown]
# ## 5.2 K-Nearest Neighbors (KNN)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
stratified_kfold_evaluation(skf, knn, x_full, y_full)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.87        25
#            1       0.69      0.44      0.54        25
#            2       0.87      0.74      0.80        27
#            3       0.61      0.85      0.71        26
#            4       0.88      0.88      0.88        32
#            5       0.93      0.96      0.94        26
#            6       1.00      0.97      0.98        29
#
#     accuracy                           0.83       190
#    macro avg       0.83      0.82      0.82       190
# weighted avg       0.83      0.83      0.82       190
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84        25
#            1       0.53      0.40      0.45        25
#            2       0.83      0.74      0.78        27
#            3       0.65      0.58      0.61        26
#            4       0.83      0.91      0.87        32
#            5       0.84      0.96      0.90        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.79       190
#    macro avg       0.78      0.79      0.78       190
# weighted avg       0.78      0.79      0.79       190
#
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89        25
#            1       0.62      0.40      0.49        25
#            2       0.63      0.70      0.67        27
#            3       0.68      0.73      0.70        26
#            4       0.81      0.78      0.79        32
#            5       0.92      0.89      0.91        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.79       190
#    macro avg       0.78      0.79      0.78       190
# weighted avg       0.79      0.79      0.78       190
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.83      0.73        24
#            1       0.61      0.42      0.50        26
#            2       0.70      0.70      0.70        27
#            3       1.00      0.73      0.84        26
#            4       0.81      0.91      0.85        32
#            5       0.84      0.96      0.90        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.80       190
#    macro avg       0.80      0.79      0.79       190
# weighted avg       0.80      0.80      0.79       190
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.96      0.85        24
#            1       0.63      0.46      0.53        26
#            2       0.76      0.70      0.73        27
#            3       0.71      0.85      0.77        26
#            4       0.78      0.78      0.78        32
#            5       0.88      0.85      0.87        27
#            6       1.00      0.96      0.98        28
#
#     accuracy                           0.79       190
#    macro avg       0.79      0.80      0.79       190
# weighted avg       0.79      0.79      0.79       190
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.92      0.77        24
#            1       0.64      0.35      0.45        26
#            2       0.70      0.70      0.70        27
#            3       0.73      0.73      0.73        26
#            4       0.73      0.69      0.71        32
#            5       0.81      0.96      0.88        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.76       190
#    macro avg       0.76      0.76      0.75       190
# weighted avg       0.76      0.76      0.75       190
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79        24
#            1       0.71      0.38      0.50        26
#            2       0.71      0.81      0.76        27
#            3       0.78      0.69      0.73        26
#            4       0.74      0.78      0.76        32
#            5       0.87      0.96      0.91        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.79       190
#    macro avg       0.79      0.79      0.78       190
# weighted avg       0.79      0.79      0.78       190
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.80      0.74        25
#            1       0.58      0.42      0.49        26
#            2       0.74      0.77      0.75        26
#            3       0.88      0.81      0.85        27
#            4       0.88      0.90      0.89        31
#            5       0.90      1.00      0.95        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.82       190
#    macro avg       0.81      0.82      0.81       190
# weighted avg       0.81      0.82      0.81       190
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.81        25
#            1       0.53      0.38      0.44        26
#            2       0.67      0.69      0.68        26
#            3       0.81      0.78      0.79        27
#            4       0.82      0.74      0.78        31
#            5       0.81      0.96      0.88        26
#            6       0.97      1.00      0.98        29
#
#     accuracy                           0.78       190
#    macro avg       0.76      0.78      0.77       190
# weighted avg       0.77      0.78      0.77       190
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.88      0.80        25
#            1       0.87      0.52      0.65        25
#            2       0.71      0.77      0.74        26
#            3       0.71      0.81      0.76        27
#            4       0.83      0.77      0.80        31
#            5       0.96      0.96      0.96        26
#            6       0.97      1.00      0.98        29
#
#     accuracy                           0.82       189
#    macro avg       0.83      0.82      0.81       189
# weighted avg       0.83      0.82      0.82       189
#
# List of possible accuracy: [0.8263157894736842, 0.7947368421052632, 0.7894736842105263, 0.8, 0.7947368421052632, 0.7631578947368421, 0.7894736842105263, 0.8210526315789474, 0.7789473684210526, 0.8201058201058201]
#
# Maximum Accuracy That can be obtained from this model is: 82.63157894736842 %
#
# Minimum Accuracy: 76.31578947368422 %
#
# Overall Accuracy: 79.78000556947926 %
#
# Standard Deviation: 1.889217523621729 %

# %%
resultados_knn = []

for k in range (2, 21):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)

    resultados_knn.append(knn.score(X_val, y_val))

# %%
resultados_knn
# Out:
# [0.8368421052631579,
#  0.8473684210526315,
#  0.8368421052631579,
#  0.8394736842105263,
#  0.8184210526315789,
#  0.8,
#  0.7947368421052632,
#  0.7868421052631579,
#  0.7710526315789473,
#  0.7710526315789473,
#  0.7684210526315789,
#  0.7631578947368421,
#  0.7631578947368421,
#  0.7552631578947369,
#  0.7657894736842106,
#  0.7552631578947369,
#  0.75,
#  0.7473684210526316,
#  0.7394736842105263]

# %%
(np.mean(resultados_knn), np.std(resultados_knn))
# Out:
# (0.7847645429362881, 0.03413670863372445)

# %%
xticks = list(range(2, 21))
plt.xlabel('N')
plt.ylabel('Accuracy')
#plt.xticks(ticks=xticks, labels=xticks)
#plt.set_xticks(xticks, labels=xticks)
sns.lineplot(x=xticks, y=resultados_knn);

# %%
y_pred = cross_val_predict(knn, x_full, y_full, cv=10)
confusion_matrix_knn = pd.crosstab(y_full, y_pred, rownames=['Atual'], colnames=['Predição'])
sns.heatmap(confusion_matrix_knn, annot=True, fmt='d');

# %% [markdown]
# ## 5.3 Decision Tree

# %%
dt = DecisionTreeClassifier()

# %%
stratified_kfold_evaluation(skf, dt, x_full, y_full)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94        25
#            1       0.92      0.92      0.92        25
#            2       0.96      0.96      0.96        27
#            3       1.00      0.88      0.94        26
#            4       0.91      1.00      0.96        32
#            5       1.00      1.00      1.00        26
#            6       1.00      0.97      0.98        29
#
#     accuracy                           0.96       190
#    macro avg       0.96      0.96      0.96       190
# weighted avg       0.96      0.96      0.96       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       0.82      0.72      0.77        25
#            2       0.74      0.85      0.79        27
#            3       1.00      0.85      0.92        26
#            4       0.94      0.97      0.95        32
#            5       0.96      1.00      0.98        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.92       190
#    macro avg       0.92      0.91      0.91       190
# weighted avg       0.92      0.92      0.92       190
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        25
#            1       0.78      0.84      0.81        25
#            2       0.88      0.78      0.82        27
#            3       0.93      0.96      0.94        26
#            4       0.94      0.97      0.95        32
#            5       0.96      0.93      0.94        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.92       190
#    macro avg       0.91      0.91      0.91       190
# weighted avg       0.92      0.92      0.92       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        24
#            1       0.88      0.88      0.88        26
#            2       0.92      0.85      0.88        27
#            3       0.93      0.96      0.94        26
#            4       0.97      0.91      0.94        32
#            5       0.93      1.00      0.96        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        24
#            1       0.96      0.88      0.92        26
#            2       0.96      0.96      0.96        27
#            3       0.93      0.96      0.94        26
#            4       0.94      0.91      0.92        32
#            5       0.96      0.93      0.94        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.95       190
#    macro avg       0.95      0.95      0.95       190
# weighted avg       0.95      0.95      0.95       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        24
#            1       0.82      0.88      0.85        26
#            2       0.91      0.78      0.84        27
#            3       0.86      0.92      0.89        26
#            4       0.94      0.91      0.92        32
#            5       0.96      1.00      0.98        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.92       190
#    macro avg       0.92      0.92      0.92       190
# weighted avg       0.92      0.92      0.92       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        24
#            1       0.86      0.96      0.91        26
#            2       0.96      0.93      0.94        27
#            3       0.93      0.96      0.94        26
#            4       0.97      0.97      0.97        32
#            5       1.00      0.96      0.98        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.96       190
#    macro avg       0.96      0.96      0.96       190
# weighted avg       0.96      0.96      0.96       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        25
#            1       0.86      0.96      0.91        26
#            2       0.92      0.92      0.92        26
#            3       0.96      0.96      0.96        27
#            4       1.00      0.94      0.97        31
#            5       0.96      1.00      0.98        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.96       190
#    macro avg       0.96      0.96      0.96       190
# weighted avg       0.96      0.96      0.96       190
#
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        25
#            1       1.00      0.85      0.92        26
#            2       0.96      0.96      0.96        26
#            3       0.82      1.00      0.90        27
#            4       0.96      0.81      0.88        31
#            5       0.93      0.96      0.94        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        25
#            1       0.87      0.80      0.83        25
#            2       0.92      0.88      0.90        26
#            3       0.89      0.93      0.91        27
#            4       0.97      0.97      0.97        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.94       189
#    macro avg       0.94      0.94      0.94       189
# weighted avg       0.94      0.94      0.94       189
#
# List of possible accuracy: [0.9578947368421052, 0.9157894736842105, 0.9157894736842105, 0.9421052631578948, 0.9473684210526315, 0.9210526315789473, 0.9578947368421052, 0.9578947368421052, 0.9368421052631579, 0.9417989417989417]
#
# Maximum Accuracy That can be obtained from this model is: 95.78947368421052 %
#
# Minimum Accuracy: 91.57894736842105 %
#
# Overall Accuracy: 93.9443052074631 %
#
# Standard Deviation: 1.6002496997733984 %

# %% [markdown]
# ## 5.4 Random Forest

# %%
rf = RandomForestClassifier()

# %%
stratified_kfold_evaluation(skf, rf, x_full, y_full)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       0.88      0.92      0.90        25
#            2       0.96      0.93      0.94        27
#            3       1.00      0.92      0.96        26
#            4       0.94      1.00      0.97        32
#            5       1.00      1.00      1.00        26
#            6       1.00      0.97      0.98        29
#
#     accuracy                           0.96       190
#    macro avg       0.96      0.96      0.96       190
# weighted avg       0.96      0.96      0.96       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        25
#            1       0.73      0.96      0.83        25
#            2       0.91      0.78      0.84        27
#            3       1.00      0.81      0.89        26
#            4       0.97      1.00      0.98        32
#            5       1.00      1.00      1.00        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.93       190
#    macro avg       0.94      0.93      0.93       190
# weighted avg       0.94      0.93      0.93       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        25
#            1       0.83      0.96      0.89        25
#            2       0.92      0.89      0.91        27
#            3       0.88      0.85      0.86        26
#            4       1.00      0.94      0.97        32
#            5       0.96      1.00      0.98        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        24
#            1       0.89      0.92      0.91        26
#            2       0.96      0.81      0.88        27
#            3       0.84      1.00      0.91        26
#            4       1.00      0.97      0.98        32
#            5       1.00      1.00      1.00        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.95       190
#    macro avg       0.95      0.95      0.95       190
# weighted avg       0.96      0.95      0.95       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        24
#            1       0.89      0.96      0.93        26
#            2       0.93      0.93      0.93        27
#            3       0.93      0.96      0.94        26
#            4       1.00      0.91      0.95        32
#            5       1.00      0.96      0.98        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.96       190
#    macro avg       0.96      0.96      0.96       190
# weighted avg       0.96      0.96      0.96       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        24
#            1       0.83      0.92      0.87        26
#            2       0.92      0.85      0.88        27
#            3       0.89      0.96      0.93        26
#            4       1.00      0.94      0.97        32
#            5       1.00      1.00      1.00        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.95       190
#    macro avg       0.95      0.95      0.95       190
# weighted avg       0.95      0.95      0.95       190
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        24
#            1       0.83      0.92      0.87        26
#            2       0.96      0.93      0.94        27
#            3       0.96      0.92      0.94        26
#            4       1.00      0.97      0.98        32
#            5       1.00      1.00      1.00        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.95       190
#    macro avg       0.95      0.95      0.95       190
# weighted avg       0.95      0.95      0.95       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94        25
#            1       0.81      0.96      0.88        26
#            2       0.96      0.88      0.92        26
#            3       1.00      0.96      0.98        27
#            4       1.00      0.97      0.98        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.96       190
#    macro avg       0.96      0.96      0.96       190
# weighted avg       0.96      0.96      0.96       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94        25
#            1       0.86      0.92      0.89        26
#            2       0.93      1.00      0.96        26
#            3       0.93      0.96      0.95        27
#            4       0.97      0.94      0.95        31
#            5       1.00      0.96      0.98        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.95       190
#    macro avg       0.95      0.95      0.95       190
# weighted avg       0.96      0.95      0.95       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.88      0.92        25
#            1       0.80      0.96      0.87        25
#            2       0.96      0.88      0.92        26
#            3       1.00      0.93      0.96        27
#            4       0.97      1.00      0.98        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.95       189
#    macro avg       0.95      0.95      0.95       189
# weighted avg       0.96      0.95      0.95       189
#
# List of possible accuracy: [0.9631578947368421, 0.9315789473684211, 0.9421052631578948, 0.9526315789473684, 0.9578947368421052, 0.9473684210526315, 0.9526315789473684, 0.9578947368421052, 0.9526315789473684, 0.9523809523809523]
#
# Maximum Accuracy That can be obtained from this model is: 96.3157894736842 %
#
# Minimum Accuracy: 93.15789473684211 %
#
# Overall Accuracy: 95.10275689223057 %
#
# Standard Deviation: 0.849856911335024 %

# %% [markdown]
# ## 5.5 Multilayer Perceptron (MLP)

# %%
mlp = MLPClassifier(max_iter=5000, random_state=16)

# %%
stratified_kfold_evaluation(skf, mlp, x_full, y_full)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92        25
#            1       0.95      0.80      0.87        25
#            2       0.90      0.96      0.93        27
#            3       0.96      0.92      0.94        26
#            4       0.94      0.97      0.95        32
#            5       0.93      0.96      0.94        26
#            6       1.00      0.97      0.98        29
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.93      0.93       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        25
#            1       0.79      0.88      0.83        25
#            2       0.78      0.78      0.78        27
#            3       0.91      0.81      0.86        26
#            4       0.97      0.97      0.97        32
#            5       1.00      1.00      1.00        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.92       190
#    macro avg       0.92      0.91      0.91       190
# weighted avg       0.92      0.92      0.92       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        25
#            1       0.88      0.92      0.90        25
#            2       0.82      0.85      0.84        27
#            3       0.85      0.85      0.85        26
#            4       0.94      0.97      0.95        32
#            5       1.00      0.93      0.96        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.93       190
#    macro avg       0.93      0.92      0.93       190
# weighted avg       0.93      0.93      0.93       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        24
#            1       0.86      0.96      0.91        26
#            2       0.96      0.81      0.88        27
#            3       0.89      0.92      0.91        26
#            4       0.91      0.97      0.94        32
#            5       1.00      0.96      0.98        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.94       190
#    macro avg       0.95      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92        24
#            1       0.90      0.69      0.78        26
#            2       0.83      0.93      0.88        27
#            3       0.96      0.92      0.94        26
#            4       0.97      0.97      0.97        32
#            5       1.00      0.96      0.98        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.93       190
#    macro avg       0.93      0.92      0.92       190
# weighted avg       0.93      0.93      0.92       190
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        24
#            1       0.77      0.77      0.77        26
#            2       0.88      0.81      0.85        27
#            3       0.89      0.96      0.93        26
#            4       1.00      0.97      0.98        32
#            5       1.00      1.00      1.00        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.92       190
#    macro avg       0.92      0.92      0.92       190
# weighted avg       0.92      0.92      0.92       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94        24
#            1       0.85      0.88      0.87        26
#            2       0.86      0.93      0.89        27
#            3       0.96      0.88      0.92        26
#            4       0.97      0.97      0.97        32
#            5       1.00      1.00      1.00        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        25
#            1       0.92      0.85      0.88        26
#            2       0.85      0.85      0.85        26
#            3       0.87      0.96      0.91        27
#            4       0.97      0.94      0.95        31
#            5       0.96      1.00      0.98        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       1.00      0.88      0.94        26
#            2       0.88      0.88      0.88        26
#            3       0.90      0.96      0.93        27
#            4       1.00      1.00      1.00        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.96       190
#    macro avg       0.96      0.96      0.96       190
# weighted avg       0.96      0.96      0.96       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94        25
#            1       0.88      0.84      0.86        25
#            2       0.88      0.88      0.88        26
#            3       0.90      0.96      0.93        27
#            4       1.00      1.00      1.00        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.95       189
#    macro avg       0.94      0.94      0.94       189
# weighted avg       0.95      0.95      0.95       189
#
# List of possible accuracy: [0.9368421052631579, 0.9157894736842105, 0.9263157894736842, 0.9421052631578948, 0.9263157894736842, 0.9210526315789473, 0.9421052631578948, 0.9368421052631579, 0.9631578947368421, 0.9470899470899471]
#
# Maximum Accuracy That can be obtained from this model is: 96.3157894736842 %
#
# Minimum Accuracy: 91.57894736842105 %
#
# Overall Accuracy: 93.57616262879421 %
#
# Standard Deviation: 1.3249127425773761 %

# %% [markdown]
# ## 5.6 Naive-Bayes

# %%
nb = GaussianNB()

# %%
stratified_kfold_evaluation(skf, nb, x_full, y_full)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.92      0.78        25
#            1       0.86      0.24      0.38        25
#            2       0.40      0.15      0.22        27
#            3       0.58      0.27      0.37        26
#            4       0.40      0.50      0.44        32
#            5       0.44      1.00      0.61        26
#            6       1.00      0.97      0.98        29
#
#     accuracy                           0.58       190
#    macro avg       0.62      0.58      0.54       190
# weighted avg       0.62      0.58      0.54       190
#
#               precision    recall  f1-score   support
#
#            0       0.69      1.00      0.82        25
#            1       0.50      0.28      0.36        25
#            2       0.67      0.30      0.41        27
#            3       0.60      0.23      0.33        26
#            4       0.44      0.50      0.47        32
#            5       0.50      1.00      0.67        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.62       190
#    macro avg       0.63      0.62      0.58       190
# weighted avg       0.63      0.62      0.58       190
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.96      0.60        25
#            1       0.14      0.04      0.06        25
#            2       0.30      0.11      0.16        27
#            3       0.56      0.19      0.29        26
#            4       0.59      0.41      0.48        32
#            5       0.44      0.96      0.60        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.53       190
#    macro avg       0.50      0.52      0.46       190
# weighted avg       0.50      0.53      0.46       190
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.83      0.69        24
#            1       0.54      0.27      0.36        26
#            2       0.62      0.30      0.40        27
#            3       0.25      0.08      0.12        26
#            4       0.47      0.44      0.45        32
#            5       0.41      0.96      0.57        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.55       190
#    macro avg       0.55      0.55      0.51       190
# weighted avg       0.55      0.55      0.51       190
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.92      0.76        24
#            1       0.62      0.31      0.41        26
#            2       0.73      0.41      0.52        27
#            3       0.50      0.12      0.19        26
#            4       0.48      0.31      0.38        32
#            5       0.33      0.93      0.49        27
#            6       1.00      0.93      0.96        28
#
#     accuracy                           0.55       190
#    macro avg       0.62      0.56      0.53       190
# weighted avg       0.61      0.55      0.53       190
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.92      0.80        24
#            1       0.57      0.31      0.40        26
#            2       0.53      0.33      0.41        27
#            3       1.00      0.12      0.21        26
#            4       0.29      0.31      0.30        32
#            5       0.44      1.00      0.61        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.56       190
#    macro avg       0.65      0.57      0.53       190
# weighted avg       0.64      0.56      0.53       190
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.96      0.87        24
#            1       0.82      0.54      0.65        26
#            2       0.50      0.26      0.34        27
#            3       0.57      0.15      0.24        26
#            4       0.44      0.59      0.51        32
#            5       0.52      1.00      0.68        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.64       190
#    macro avg       0.66      0.64      0.61       190
# weighted avg       0.66      0.64      0.61       190
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.84      0.71        25
#            1       0.53      0.31      0.39        26
#            2       0.30      0.12      0.17        26
#            3       0.80      0.15      0.25        27
#            4       0.37      0.48      0.42        31
#            5       0.46      1.00      0.63        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.56       190
#    macro avg       0.58      0.56      0.51       190
# weighted avg       0.58      0.56      0.51       190
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83        25
#            1       0.58      0.27      0.37        26
#            2       0.56      0.38      0.45        26
#            3       0.61      0.41      0.49        27
#            4       0.44      0.45      0.44        31
#            5       0.50      1.00      0.67        26
#            6       0.97      1.00      0.98        29
#
#     accuracy                           0.63       190
#    macro avg       0.63      0.63      0.61       190
# weighted avg       0.63      0.63      0.61       190
#
#               precision    recall  f1-score   support
#
#            0       0.68      1.00      0.81        25
#            1       0.62      0.32      0.42        25
#            2       0.69      0.35      0.46        26
#            3       0.71      0.19      0.29        27
#            4       0.42      0.45      0.44        31
#            5       0.46      1.00      0.63        26
#            6       0.97      1.00      0.98        29
#
#     accuracy                           0.61       189
#    macro avg       0.65      0.61      0.58       189
# weighted avg       0.65      0.61      0.58       189
#
# List of possible accuracy: [0.5789473684210527, 0.6157894736842106, 0.5263157894736842, 0.5526315789473685, 0.5526315789473685, 0.5631578947368421, 0.6421052631578947, 0.5578947368421052, 0.6263157894736842, 0.6137566137566137]
#
# Maximum Accuracy That can be obtained from this model is: 64.21052631578948 %
#
# Minimum Accuracy: 52.63157894736842 %
#
# Overall Accuracy: 58.29546087440824 %
#
# Standard Deviation: 3.672707031735587 %

# %% [markdown]
# ## 5.7 Support Vector Machine (SVM)

# %%
svm = SVC()

# %%
stratified_kfold_evaluation(skf, svm, x_full, y_full)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.84      0.79        25
#            1       0.77      0.40      0.53        25
#            2       0.67      0.59      0.63        27
#            3       0.55      0.65      0.60        26
#            4       0.71      0.75      0.73        32
#            5       0.78      0.96      0.86        26
#            6       1.00      0.97      0.98        29
#
#     accuracy                           0.74       190
#    macro avg       0.75      0.74      0.73       190
# weighted avg       0.75      0.74      0.73       190
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.92      0.85        25
#            1       0.65      0.52      0.58        25
#            2       0.82      0.67      0.73        27
#            3       0.65      0.58      0.61        26
#            4       0.74      0.78      0.76        32
#            5       0.79      1.00      0.89        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.78       190
#    macro avg       0.78      0.78      0.77       190
# weighted avg       0.78      0.78      0.78       190
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94        25
#            1       0.58      0.60      0.59        25
#            2       0.57      0.59      0.58        27
#            3       0.52      0.42      0.47        26
#            4       0.69      0.56      0.62        32
#            5       0.74      0.93      0.82        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.72       190
#    macro avg       0.71      0.72      0.71       190
# weighted avg       0.71      0.72      0.71       190
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89        24
#            1       0.68      0.50      0.58        26
#            2       0.55      0.67      0.60        27
#            3       0.74      0.54      0.62        26
#            4       0.70      0.81      0.75        32
#            5       0.87      0.96      0.91        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.77       190
#    macro avg       0.77      0.77      0.76       190
# weighted avg       0.77      0.77      0.76       190
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.96      0.87        24
#            1       0.72      0.50      0.59        26
#            2       0.62      0.74      0.68        27
#            3       0.67      0.54      0.60        26
#            4       0.68      0.66      0.67        32
#            5       0.78      0.93      0.85        27
#            6       1.00      0.96      0.98        28
#
#     accuracy                           0.75       190
#    macro avg       0.75      0.75      0.75       190
# weighted avg       0.75      0.75      0.75       190
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.88      0.76        24
#            1       0.60      0.46      0.52        26
#            2       0.59      0.63      0.61        27
#            3       0.68      0.58      0.62        26
#            4       0.80      0.62      0.70        32
#            5       0.74      0.96      0.84        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.73       190
#    macro avg       0.73      0.73      0.72       190
# weighted avg       0.73      0.73      0.72       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94        24
#            1       0.87      0.50      0.63        26
#            2       0.46      0.67      0.55        27
#            3       0.61      0.54      0.57        26
#            4       0.73      0.69      0.71        32
#            5       0.84      0.96      0.90        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.75       190
#    macro avg       0.78      0.75      0.75       190
# weighted avg       0.77      0.75      0.75       190
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84        25
#            1       0.57      0.50      0.53        26
#            2       0.57      0.65      0.61        26
#            3       0.74      0.63      0.68        27
#            4       0.72      0.68      0.70        31
#            5       0.87      1.00      0.93        26
#            6       0.97      1.00      0.98        29
#
#     accuracy                           0.76       190
#    macro avg       0.75      0.76      0.75       190
# weighted avg       0.75      0.76      0.75       190
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83        25
#            1       0.69      0.42      0.52        26
#            2       0.65      0.77      0.70        26
#            3       0.73      0.81      0.77        27
#            4       0.85      0.74      0.79        31
#            5       0.89      0.96      0.93        26
#            6       0.97      1.00      0.98        29
#
#     accuracy                           0.80       190
#    macro avg       0.79      0.80      0.79       190
# weighted avg       0.80      0.80      0.79       190
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.88      0.80        25
#            1       0.62      0.32      0.42        25
#            2       0.78      0.81      0.79        26
#            3       0.64      0.67      0.65        27
#            4       0.70      0.68      0.69        31
#            5       0.81      0.96      0.88        26
#            6       0.97      1.00      0.98        29
#
#     accuracy                           0.76       189
#    macro avg       0.75      0.76      0.75       189
# weighted avg       0.75      0.76      0.75       189
#
# List of possible accuracy: [0.7421052631578947, 0.7842105263157895, 0.7210526315789474, 0.7684210526315789, 0.7526315789473684, 0.7315789473684211, 0.7526315789473684, 0.7578947368421053, 0.8, 0.7619047619047619]
#
# Maximum Accuracy That can be obtained from this model is: 80.0 %
#
# Minimum Accuracy: 72.10526315789474 %
#
# Overall Accuracy: 75.72431077694235 %
#
# Standard Deviation: 2.223191853834744 %

# %% [markdown]
# # 6.0 Hyperparameter Fine Tuning

# %% [markdown]
# ## 6.1 Grid Search

# %% [markdown]
# ## 6.1.1 KNN

# %%
# knn_param = [
#     {'n_neighbors': np.arange(2, 21),
#      'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#      'weights': ['uniform', 'distance'],
#      'metric': ['euclidean', 'manhattan', 'chebyshev']},
    
#      {'n_neighbors': np.arange(2, 21),
#       'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#       'weights': ['uniform', 'distance'],
#       'metric': ['seuclidean', 'mahalanobis'],
#       'metric_params': [{'V': np.cov(x_full)}]}
# ]

# %%
knn_param = {
    'n_neighbors': np.arange(2, 21),
     'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
     'weights': ['uniform', 'distance'],
     'metric': ['euclidean', 'manhattan', 'chebyshev']
}

# %%
grid_search = GridSearchCV(estimator=knn, param_grid=knn_param, cv=skf.split(x_full, y_full))
grid_search.fit(x_full, y_full)
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# 0.870465051517683
# {'algorithm': 'auto', 'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}

# %%
# {'algorithm': 'auto', 'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}

# %% [markdown]
# ## 6.1.2 Decision Tree

# %%
dt_param = {
    'max_depth': [None, 3, 5, 9, 12, 15],
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'min_samples_split': [2, 4, 6, 8],
    'min_samples_leaf': [1, 2, 3, 4, 5],
    'max_features': [None, 'auto', 'sqrt', 'log2']    
}

# %%
grid_search = GridSearchCV(estimator=dt, param_grid=dt_param, cv=skf.split(x_full, y_full))
grid_search.fit(x_full, y_full)
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# 0.9505068226120859
# {'criterion': 'entropy', 'max_depth': 15, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}

# %%
# {'criterion': 'entropy', 'max_depth': 12, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}

# %% [markdown]
# ## 6.1.3 Random Forest

# %%
rf_param = {
    'estimator__max_depth': [None, 3, 5, 9, 12, 15],
    'estimator__criterion': ['gini', 'entropy'],
    'estimator__plitter': ['best', 'random'],
    'estimator__min_samples_split': [2, 4, 6, 8],
    'estimator__min_samples_leaf': [1, 2, 3, 4, 5],
    'estimator__max_features': ['auto', 'sqrt', 'log2']    
}

# %%
rf.get_params().keys()
# Out:
# dict_keys(['bootstrap', 'ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])

# %%
# algum erro estranho está impedindo o grid search de rodar para a random forest

#grid_search = GridSearchCV(estimator=rf, param_grid=rf_param, cv=skf.split(x_full, y_full))
#grid_search.fit(x_full, y_full)

# %%
for param in grid_search.get_params().keys():
    print(param)
# Out:
# cv
# error_score
# estimator__ccp_alpha
# estimator__class_weight
# estimator__criterion
# estimator__max_depth
# estimator__max_features
# estimator__max_leaf_nodes
# estimator__min_impurity_decrease
# estimator__min_samples_leaf
# estimator__min_samples_split
# estimator__min_weight_fraction_leaf
# estimator__random_state
# estimator__splitter
# estimator
# n_jobs
# param_grid
# pre_dispatch
# refit
# return_train_score
# scoring
# verbose

# %% [markdown]
# ## 6.1.4 MLP

# %%
mlp_param = {
    'random_state':[16],
    'activation':['tanh', 'relu', 'identity', 'logistic'],
    'solver':['lbfgs', 'sgd', 'adam'],
    'alpha':[0.01, 0.001, 0.0001, 0.00001]
}

# %%
grid_search = GridSearchCV(estimator=mlp, param_grid=mlp_param, cv=skf.split(x_full, y_full))
grid_search.fit(x_full, y_full)
print(grid_search.best_score_)
print(grid_search.best_params_)

# %%
# {'activation': 'identity', 'alpha': 0.01, 'solver': 'lbfgs'}

# %% [markdown]
# ## 6.1.5 Naive Bayes

# %%
nb_param = {
    'var_smoothing':[1e-09, 1e-08, 1e-07, 1e-06, 1e-05, 1e-04, 1e-03, 1e-02, 1e-01]
}

# %%
# Sem hiperparametros para tunar
grid_search = GridSearchCV(estimator=nb, param_grid=nb_param, cv=skf.split(x_full, y_full))
grid_search.fit(x_full, y_full)
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# 0.5987357282094125
# {'var_smoothing': 0.001}

# %%
# {'var_smoothing': 0.001}

# %% [markdown]
# ## 6.1.6 SVM

# %%
svm_param = {
    'C': [0.1, 0.3, 0.5, 0.75, 1],
    'kernel': ['linear', 'rbf', 'sigmoid']
}

# %%
grid_search = GridSearchCV(estimator=svm, param_grid=svm_param, cv=skf.split(x_full, y_full))
grid_search.fit(x_full, y_full)
print(grid_search.best_score_)
print(grid_search.best_params_)

# %%
# C=1, kernel='linear'

# %% [markdown]
# # 7. Final Models

# %% [markdown]
# FAZER TABELA COM OS RESULTADOS ANTES E DEPOIS DO GRID SEARCH

# %% [markdown]
# E COMPARAR OS OS RESULTADOS USANDO TODOS OS FEATURES, E TIRANDO O SMOKE E OUTRO LÁ

# %% [markdown]
# ## 7.1 Final Models with all features

# %%
knn2 = KNeighborsClassifier(algorithm='auto', metric='manhattan', n_neighbors=4, weights='distance')
stratified_kfold_evaluation(skf, knn2, x_full, y_full)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        25
#            1       0.83      0.60      0.70        25
#            2       0.85      0.81      0.83        27
#            3       0.79      0.85      0.81        26
#            4       0.91      0.97      0.94        32
#            5       0.93      1.00      0.96        26
#            6       1.00      0.97      0.98        29
#
#     accuracy                           0.89       190
#    macro avg       0.89      0.89      0.88       190
# weighted avg       0.89      0.89      0.89       190
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        25
#            1       0.65      0.60      0.63        25
#            2       0.83      0.70      0.76        27
#            3       0.78      0.81      0.79        26
#            4       0.89      0.97      0.93        32
#            5       0.93      0.96      0.95        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.86       190
#    macro avg       0.85      0.85      0.85       190
# weighted avg       0.85      0.86      0.85       190
#
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        25
#            1       0.71      0.60      0.65        25
#            2       0.74      0.63      0.68        27
#            3       0.74      0.77      0.75        26
#            4       0.81      0.91      0.85        32
#            5       0.93      0.93      0.93        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.84       190
#    macro avg       0.83      0.83      0.83       190
# weighted avg       0.83      0.84      0.83       190
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.92      0.88        24
#            1       0.76      0.50      0.60        26
#            2       0.78      0.78      0.78        27
#            3       0.96      0.88      0.92        26
#            4       0.78      1.00      0.88        32
#            5       0.96      0.96      0.96        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.87       190
#    macro avg       0.87      0.86      0.86       190
# weighted avg       0.87      0.87      0.86       190
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90        24
#            1       0.76      0.62      0.68        26
#            2       0.77      0.74      0.75        27
#            3       0.82      0.88      0.85        26
#            4       0.84      0.84      0.84        32
#            5       0.93      0.96      0.95        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.86       190
#    macro avg       0.85      0.86      0.85       190
# weighted avg       0.86      0.86      0.85       190
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.92      0.85        24
#            1       0.62      0.50      0.55        26
#            2       0.80      0.74      0.77        27
#            3       0.82      0.88      0.85        26
#            4       0.94      0.91      0.92        32
#            5       0.93      1.00      0.96        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.85       190
#    macro avg       0.84      0.85      0.84       190
# weighted avg       0.85      0.85      0.85       190
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86        24
#            1       0.77      0.65      0.71        26
#            2       0.81      0.81      0.81        27
#            3       0.95      0.77      0.85        26
#            4       0.82      1.00      0.90        32
#            5       1.00      1.00      1.00        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.88       190
#    macro avg       0.88      0.87      0.87       190
# weighted avg       0.88      0.88      0.88       190
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.82        25
#            1       0.71      0.58      0.64        26
#            2       0.79      0.88      0.84        26
#            3       0.92      0.85      0.88        27
#            4       0.81      0.94      0.87        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.87       190
#    macro avg       0.87      0.86      0.86       190
# weighted avg       0.87      0.87      0.87       190
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92        25
#            1       0.83      0.73      0.78        26
#            2       0.85      0.88      0.87        26
#            3       0.92      0.89      0.91        27
#            4       0.88      0.90      0.89        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.91       190
#    macro avg       0.91      0.91      0.91       190
# weighted avg       0.91      0.91      0.91       190
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86        25
#            1       0.81      0.68      0.74        25
#            2       0.79      0.85      0.81        26
#            3       0.89      0.89      0.89        27
#            4       0.87      0.87      0.87        31
#            5       0.96      1.00      0.98        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.88       189
#    macro avg       0.88      0.88      0.88       189
# weighted avg       0.88      0.88      0.88       189
#
# List of possible accuracy: [0.8894736842105263, 0.8578947368421053, 0.8368421052631579, 0.868421052631579, 0.8578947368421053, 0.8526315789473684, 0.8789473684210526, 0.868421052631579, 0.9105263157894737, 0.8835978835978836]
#
# Maximum Accuracy That can be obtained from this model is: 91.05263157894737 %
#
# Minimum Accuracy: 83.6842105263158 %
#
# Overall Accuracy: 87.0465051517683 %
#
# Standard Deviation: 1.995888457337069 %

# %%
svm2 = SVC(C=1, kernel='linear')
stratified_kfold_evaluation(skf, svm2, x_full, y_full)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.96      0.86        25
#            1       0.80      0.48      0.60        25
#            2       0.75      0.56      0.64        27
#            3       0.57      0.77      0.66        26
#            4       0.84      0.84      0.84        32
#            5       0.90      1.00      0.95        26
#            6       1.00      0.97      0.98        29
#
#     accuracy                           0.80       190
#    macro avg       0.81      0.80      0.79       190
# weighted avg       0.81      0.80      0.79       190
#
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86        25
#            1       0.67      0.48      0.56        25
#            2       0.89      0.63      0.74        27
#            3       0.65      0.77      0.70        26
#            4       0.88      0.88      0.88        32
#            5       0.93      1.00      0.96        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.83       190
#    macro avg       0.82      0.82      0.81       190
# weighted avg       0.83      0.83      0.82       190
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94        25
#            1       0.76      0.64      0.70        25
#            2       0.61      0.70      0.66        27
#            3       0.65      0.58      0.61        26
#            4       0.85      0.72      0.78        32
#            5       0.82      1.00      0.90        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.80       190
#    macro avg       0.80      0.80      0.80       190
# weighted avg       0.80      0.80      0.80       190
#
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86        24
#            1       0.87      0.50      0.63        26
#            2       0.73      0.70      0.72        27
#            3       0.67      0.77      0.71        26
#            4       0.97      0.91      0.94        32
#            5       0.93      1.00      0.96        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.84       190
#    macro avg       0.84      0.84      0.83       190
# weighted avg       0.85      0.84      0.84       190
#
#               precision    recall  f1-score   support
#
#            0       0.73      1.00      0.84        24
#            1       0.79      0.42      0.55        26
#            2       0.74      0.93      0.82        27
#            3       0.84      0.81      0.82        26
#            4       0.89      0.78      0.83        32
#            5       0.90      0.96      0.93        27
#            6       1.00      0.96      0.98        28
#
#     accuracy                           0.84       190
#    macro avg       0.84      0.84      0.83       190
# weighted avg       0.84      0.84      0.83       190
#
#               precision    recall  f1-score   support
#
#            0       0.73      1.00      0.84        24
#            1       0.70      0.54      0.61        26
#            2       0.73      0.70      0.72        27
#            3       0.70      0.73      0.72        26
#            4       0.88      0.66      0.75        32
#            5       0.78      0.93      0.85        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.79       190
#    macro avg       0.79      0.79      0.78       190
# weighted avg       0.79      0.79      0.78       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        24
#            1       0.90      0.69      0.78        26
#            2       0.62      0.67      0.64        27
#            3       0.63      0.73      0.68        26
#            4       0.94      0.91      0.92        32
#            5       0.93      0.96      0.95        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.85       190
#    macro avg       0.85      0.85      0.85       190
# weighted avg       0.86      0.85      0.85       190
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89        25
#            1       0.78      0.54      0.64        26
#            2       0.60      0.81      0.69        26
#            3       0.81      0.63      0.71        27
#            4       0.90      0.87      0.89        31
#            5       0.93      1.00      0.96        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.83       190
#    macro avg       0.83      0.83      0.82       190
# weighted avg       0.84      0.83      0.83       190
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92        25
#            1       0.81      0.50      0.62        26
#            2       0.71      0.77      0.74        26
#            3       0.69      0.93      0.79        27
#            4       0.96      0.87      0.92        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.86       190
#    macro avg       0.87      0.86      0.86       190
# weighted avg       0.87      0.86      0.86       190
#
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85        25
#            1       0.86      0.48      0.62        25
#            2       0.74      0.88      0.81        26
#            3       0.83      0.74      0.78        27
#            4       0.89      0.81      0.85        31
#            5       0.89      0.96      0.93        26
#            6       0.97      1.00      0.98        29
#
#     accuracy                           0.84       189
#    macro avg       0.85      0.84      0.83       189
# weighted avg       0.85      0.84      0.83       189
#
# List of possible accuracy: [0.8, 0.8263157894736842, 0.8, 0.8421052631578947, 0.8368421052631579, 0.7894736842105263, 0.8473684210526315, 0.8315789473684211, 0.8631578947368421, 0.8412698412698413]
#
# Maximum Accuracy That can be obtained from this model is: 86.31578947368422 %
#
# Minimum Accuracy: 78.94736842105263 %
#
# Overall Accuracy: 82.78111946533 %
#
# Standard Deviation: 2.2653938335414443 %

# %%
dt2 = DecisionTreeClassifier(criterion='entropy', max_depth=12, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter='best')
stratified_kfold_evaluation(skf, dt2, x_full, y_full)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        25
#            1       0.96      1.00      0.98        25
#            2       0.96      1.00      0.98        27
#            3       1.00      0.88      0.94        26
#            4       0.94      1.00      0.97        32
#            5       0.96      1.00      0.98        26
#            6       1.00      0.97      0.98        29
#
#     accuracy                           0.97       190
#    macro avg       0.98      0.97      0.97       190
# weighted avg       0.97      0.97      0.97       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       0.90      0.76      0.83        25
#            2       0.71      0.93      0.81        27
#            3       0.95      0.77      0.85        26
#            4       0.91      0.91      0.91        32
#            5       1.00      1.00      1.00        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.91       190
#    macro avg       0.92      0.91      0.91       190
# weighted avg       0.92      0.91      0.91       190
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94        25
#            1       0.91      0.84      0.87        25
#            2       0.89      0.93      0.91        27
#            3       0.96      0.92      0.94        26
#            4       0.94      0.97      0.95        32
#            5       0.96      0.96      0.96        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        24
#            1       0.89      0.92      0.91        26
#            2       0.96      0.85      0.90        27
#            3       0.93      0.96      0.94        26
#            4       0.91      0.97      0.94        32
#            5       0.96      0.93      0.94        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        24
#            1       0.96      0.92      0.94        26
#            2       0.96      0.93      0.94        27
#            3       0.88      0.88      0.88        26
#            4       0.91      0.91      0.91        32
#            5       0.96      0.93      0.94        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        24
#            1       0.86      0.92      0.89        26
#            2       0.92      0.85      0.88        27
#            3       0.92      0.92      0.92        26
#            4       0.91      0.94      0.92        32
#            5       0.96      0.96      0.96        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        24
#            1       0.93      0.96      0.94        26
#            2       0.92      0.89      0.91        27
#            3       0.93      0.96      0.94        26
#            4       1.00      0.97      0.98        32
#            5       1.00      1.00      1.00        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.97       190
#    macro avg       0.97      0.97      0.97       190
# weighted avg       0.97      0.97      0.97       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        25
#            1       0.85      0.85      0.85        26
#            2       0.88      0.85      0.86        26
#            3       0.93      0.96      0.95        27
#            4       0.97      1.00      0.98        31
#            5       1.00      0.96      0.98        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        25
#            1       0.92      0.92      0.92        26
#            2       0.93      0.96      0.94        26
#            3       0.96      0.93      0.94        27
#            4       0.94      0.94      0.94        31
#            5       1.00      0.92      0.96        26
#            6       0.94      1.00      0.97        29
#
#     accuracy                           0.95       190
#    macro avg       0.95      0.95      0.95       190
# weighted avg       0.95      0.95      0.95       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        25
#            1       0.96      0.92      0.94        25
#            2       0.89      0.96      0.93        26
#            3       0.93      0.93      0.93        27
#            4       0.94      0.97      0.95        31
#            5       1.00      0.96      0.98        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.96       189
#    macro avg       0.96      0.96      0.96       189
# weighted avg       0.96      0.96      0.96       189
#
# List of possible accuracy: [0.9736842105263158, 0.9105263157894737, 0.9421052631578948, 0.9421052631578948, 0.9368421052631579, 0.9368421052631579, 0.968421052631579, 0.9421052631578948, 0.9473684210526315, 0.9576719576719577]
#
# Maximum Accuracy That can be obtained from this model is: 97.36842105263158 %
#
# Minimum Accuracy: 91.05263157894737 %
#
# Overall Accuracy: 94.57671957671957 %
#
# Standard Deviation: 1.6965575664375805 %

# %%
mlp2 = MLPClassifier(activation='identity', alpha=0.01, solver='lbfgs', max_iter=5000, random_state=16)
stratified_kfold_evaluation(skf, mlp2, x_full, y_full)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       1.00      0.96      0.98        25
#            2       0.96      0.93      0.94        27
#            3       0.93      0.96      0.94        26
#            4       1.00      0.97      0.98        32
#            5       0.93      1.00      0.96        26
#            6       1.00      0.97      0.98        29
#
#     accuracy                           0.97       190
#    macro avg       0.97      0.97      0.97       190
# weighted avg       0.97      0.97      0.97       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        25
#            1       0.89      0.96      0.92        25
#            2       0.90      0.96      0.93        27
#            3       1.00      0.92      0.96        26
#            4       1.00      1.00      1.00        32
#            5       1.00      1.00      1.00        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.97       190
#    macro avg       0.97      0.97      0.97       190
# weighted avg       0.97      0.97      0.97       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       1.00      0.84      0.91        25
#            2       0.75      0.89      0.81        27
#            3       0.88      0.81      0.84        26
#            4       0.97      1.00      0.98        32
#            5       1.00      0.93      0.96        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.93       190
#    macro avg       0.93      0.92      0.93       190
# weighted avg       0.93      0.93      0.93       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        24
#            1       0.93      1.00      0.96        26
#            2       1.00      0.93      0.96        27
#            3       1.00      1.00      1.00        26
#            4       1.00      0.97      0.98        32
#            5       1.00      1.00      1.00        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.98       190
#    macro avg       0.98      0.98      0.98       190
# weighted avg       0.99      0.98      0.98       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        24
#            1       1.00      0.96      0.98        26
#            2       0.96      0.96      0.96        27
#            3       0.96      0.96      0.96        26
#            4       1.00      1.00      1.00        32
#            5       0.96      0.96      0.96        27
#            6       0.96      0.96      0.96        28
#
#     accuracy                           0.97       190
#    macro avg       0.97      0.97      0.97       190
# weighted avg       0.97      0.97      0.97       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        24
#            1       0.90      1.00      0.95        26
#            2       0.96      0.81      0.88        27
#            3       0.86      0.96      0.91        26
#            4       1.00      0.91      0.95        32
#            5       0.93      1.00      0.96        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.95       190
#    macro avg       0.95      0.95      0.95       190
# weighted avg       0.95      0.95      0.95       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        24
#            1       1.00      0.92      0.96        26
#            2       0.90      0.96      0.93        27
#            3       0.93      0.96      0.94        26
#            4       1.00      0.94      0.97        32
#            5       0.96      0.96      0.96        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.96       190
#    macro avg       0.96      0.96      0.96       190
# weighted avg       0.96      0.96      0.96       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       1.00      0.96      0.98        26
#            2       0.93      0.96      0.94        26
#            3       0.96      0.93      0.94        27
#            4       1.00      1.00      1.00        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.98       190
#    macro avg       0.98      0.98      0.98       190
# weighted avg       0.98      0.98      0.98       190
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94        25
#            1       0.96      0.88      0.92        26
#            2       0.96      0.96      0.96        26
#            3       0.96      1.00      0.98        27
#            4       1.00      1.00      1.00        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.97       190
#    macro avg       0.97      0.97      0.97       190
# weighted avg       0.97      0.97      0.97       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       1.00      0.92      0.96        25
#            2       0.92      0.92      0.92        26
#            3       0.93      0.96      0.95        27
#            4       1.00      1.00      1.00        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.97       189
#    macro avg       0.97      0.97      0.97       189
# weighted avg       0.97      0.97      0.97       189
#
# List of possible accuracy: [0.968421052631579, 0.968421052631579, 0.9263157894736842, 0.9842105263157894, 0.9736842105263158, 0.9473684210526315, 0.9631578947368421, 0.9789473684210527, 0.9736842105263158, 0.9735449735449735]
#
# Maximum Accuracy That can be obtained from this model is: 98.42105263157895 %
#
# Minimum Accuracy: 92.63157894736842 %
#
# Overall Accuracy: 96.57755499860762 %
#
# Standard Deviation: 1.6172654393903498 %

# %% [markdown]
# ## 7.2 Final Models without Smoke and SCC

# %%
x_full_select, x_test_select, y_full_select, y_test_select = train_test_split(df2.drop(['NObeyesdad', 'target', 'SMOKE', 'SCC'], axis=1), df2['target'], random_state = 16, train_size=0.90)

print('\nTamanho treino: {}'.format(x_full_select.shape[0]))
print('Tamanho teste: {}'.format(x_test_select.shape[0]))
# Out:
# Tamanho treino: 1899
# Tamanho teste: 212

# %%
x_full_select.shape
# Out:
# (1899, 14)

# %%
X_train_select, X_val_select, y_train, y_val = train_test_split(x_full_select, y_full_select, random_state = 16, train_size=0.80)

print('\nTamanho treino: {}'.format(X_train_select.shape[0]))
print('Tamanho validação: {}'.format(X_val_select.shape[0]))
# Out:
# Tamanho treino: 1519
# Tamanho validação: 380

# %%
knn2 = KNeighborsClassifier(algorithm='auto', metric='manhattan', n_neighbors=4, weights='distance')
stratified_kfold_evaluation(skf, knn2, x_full_select, y_full_select)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        25
#            1       0.78      0.56      0.65        25
#            2       0.78      0.78      0.78        27
#            3       0.79      0.85      0.81        26
#            4       0.91      0.97      0.94        32
#            5       0.93      1.00      0.96        26
#            6       1.00      0.97      0.98        29
#
#     accuracy                           0.88       190
#    macro avg       0.87      0.87      0.87       190
# weighted avg       0.88      0.88      0.87       190
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        25
#            1       0.58      0.60      0.59        25
#            2       0.82      0.67      0.73        27
#            3       0.81      0.81      0.81        26
#            4       0.88      0.94      0.91        32
#            5       0.93      0.96      0.95        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.85       190
#    macro avg       0.84      0.84      0.84       190
# weighted avg       0.85      0.85      0.85       190
#
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        25
#            1       0.71      0.60      0.65        25
#            2       0.71      0.63      0.67        27
#            3       0.77      0.77      0.77        26
#            4       0.81      0.91      0.85        32
#            5       0.93      0.93      0.93        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.84       190
#    macro avg       0.83      0.83      0.83       190
# weighted avg       0.83      0.84      0.83       190
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.92      0.88        24
#            1       0.81      0.50      0.62        26
#            2       0.75      0.78      0.76        27
#            3       0.96      0.85      0.90        26
#            4       0.78      1.00      0.88        32
#            5       0.93      0.96      0.95        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.86       190
#    macro avg       0.87      0.86      0.85       190
# weighted avg       0.87      0.86      0.86       190
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.96      0.88        24
#            1       0.75      0.69      0.72        26
#            2       0.80      0.74      0.77        27
#            3       0.88      0.88      0.88        26
#            4       0.84      0.84      0.84        32
#            5       0.93      0.96      0.95        27
#            6       1.00      0.96      0.98        28
#
#     accuracy                           0.86       190
#    macro avg       0.86      0.86      0.86       190
# weighted avg       0.86      0.86      0.86       190
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.92      0.83        24
#            1       0.63      0.46      0.53        26
#            2       0.79      0.70      0.75        27
#            3       0.77      0.88      0.82        26
#            4       0.94      0.91      0.92        32
#            5       0.93      1.00      0.96        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.84       190
#    macro avg       0.83      0.84      0.83       190
# weighted avg       0.84      0.84      0.84       190
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86        24
#            1       0.77      0.65      0.71        26
#            2       0.81      0.81      0.81        27
#            3       0.91      0.77      0.83        26
#            4       0.84      1.00      0.91        32
#            5       1.00      1.00      1.00        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.88       190
#    macro avg       0.88      0.87      0.87       190
# weighted avg       0.88      0.88      0.88       190
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84        25
#            1       0.71      0.58      0.64        26
#            2       0.79      0.88      0.84        26
#            3       0.92      0.85      0.88        27
#            4       0.83      0.94      0.88        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.87       190
#    macro avg       0.87      0.87      0.87       190
# weighted avg       0.87      0.87      0.87       190
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        25
#            1       0.73      0.62      0.67        26
#            2       0.76      0.85      0.80        26
#            3       0.89      0.89      0.89        27
#            4       0.90      0.90      0.90        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.88       190
#    macro avg       0.88      0.88      0.88       190
# weighted avg       0.88      0.88      0.88       190
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90        25
#            1       0.79      0.76      0.78        25
#            2       0.84      0.81      0.82        26
#            3       0.92      0.85      0.88        27
#            4       0.77      0.87      0.82        31
#            5       0.96      1.00      0.98        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.88       189
#    macro avg       0.89      0.88      0.88       189
# weighted avg       0.89      0.88      0.88       189
#
# List of possible accuracy: [0.8789473684210526, 0.8473684210526315, 0.8368421052631579, 0.8631578947368421, 0.8631578947368421, 0.8421052631578947, 0.8789473684210526, 0.8736842105263158, 0.8842105263157894, 0.8835978835978836]
#
# Maximum Accuracy That can be obtained from this model is: 88.42105263157895 %
#
# Minimum Accuracy: 83.6842105263158 %
#
# Overall Accuracy: 86.52018936229462 %
#
# Standard Deviation: 1.677404829005048 %

# %%
dt2 = DecisionTreeClassifier(criterion='entropy', max_depth=12, max_features=None, min_samples_leaf=1, min_samples_split=2, splitter='best')
stratified_kfold_evaluation(skf, dt2, x_full_select, y_full_select)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        25
#            1       0.96      1.00      0.98        25
#            2       0.96      0.96      0.96        27
#            3       0.96      0.88      0.92        26
#            4       0.91      1.00      0.96        32
#            5       1.00      1.00      1.00        26
#            6       1.00      0.97      0.98        29
#
#     accuracy                           0.97       190
#    macro avg       0.97      0.97      0.97       190
# weighted avg       0.97      0.97      0.97       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       0.92      0.88      0.90        25
#            2       0.83      0.93      0.88        27
#            3       0.95      0.77      0.85        26
#            4       0.91      0.97      0.94        32
#            5       1.00      1.00      1.00        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.93      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        25
#            1       0.92      0.92      0.92        25
#            2       0.93      0.93      0.93        27
#            3       0.96      0.92      0.94        26
#            4       0.94      0.97      0.95        32
#            5       0.96      0.96      0.96        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.95       190
#    macro avg       0.95      0.95      0.95       190
# weighted avg       0.95      0.95      0.95       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        24
#            1       0.92      0.92      0.92        26
#            2       0.96      0.96      0.96        27
#            3       1.00      0.96      0.98        26
#            4       0.91      0.94      0.92        32
#            5       0.96      0.93      0.94        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.95       190
#    macro avg       0.95      0.95      0.95       190
# weighted avg       0.95      0.95      0.95       190
#
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        24
#            1       0.96      0.88      0.92        26
#            2       0.96      0.93      0.94        27
#            3       0.88      0.88      0.88        26
#            4       0.94      0.91      0.92        32
#            5       0.96      0.96      0.96        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        24
#            1       0.89      0.96      0.93        26
#            2       0.96      0.85      0.90        27
#            3       0.89      0.92      0.91        26
#            4       0.91      0.91      0.91        32
#            5       0.93      0.96      0.95        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.94      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        24
#            1       0.93      0.96      0.94        26
#            2       0.92      0.89      0.91        27
#            3       0.93      0.96      0.94        26
#            4       1.00      0.97      0.98        32
#            5       1.00      1.00      1.00        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.97       190
#    macro avg       0.97      0.97      0.97       190
# weighted avg       0.97      0.97      0.97       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        25
#            1       0.85      0.88      0.87        26
#            2       0.88      0.81      0.84        26
#            3       0.93      0.96      0.95        27
#            4       0.97      0.97      0.97        31
#            5       0.96      0.96      0.96        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.94       190
#    macro avg       0.93      0.93      0.93       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        25
#            1       0.92      0.92      0.92        26
#            2       0.93      0.96      0.94        26
#            3       0.96      0.89      0.92        27
#            4       0.91      0.94      0.92        31
#            5       0.96      0.96      0.96        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.95       190
#    macro avg       0.95      0.95      0.95       190
# weighted avg       0.95      0.95      0.95       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        25
#            1       0.96      0.88      0.92        25
#            2       0.86      0.96      0.91        26
#            3       0.93      0.93      0.93        27
#            4       0.94      0.97      0.95        31
#            5       1.00      0.96      0.98        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.95       189
#    macro avg       0.95      0.95      0.95       189
# weighted avg       0.95      0.95      0.95       189
#
# List of possible accuracy: [0.968421052631579, 0.9368421052631579, 0.9526315789473684, 0.9526315789473684, 0.9368421052631579, 0.9368421052631579, 0.968421052631579, 0.9368421052631579, 0.9473684210526315, 0.9523809523809523]
#
# Maximum Accuracy That can be obtained from this model is: 96.84210526315789 %
#
# Minimum Accuracy: 93.6842105263158 %
#
# Overall Accuracy: 94.89223057644111 %
#
# Standard Deviation: 1.1772941198311124 %

# %%
mlp2 = MLPClassifier(activation='identity', alpha=0.01, solver='lbfgs', max_iter=5000, random_state=16)
stratified_kfold_evaluation(skf, mlp2, x_full_select, y_full_select)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       1.00      0.92      0.96        25
#            2       0.93      0.93      0.93        27
#            3       0.93      0.96      0.94        26
#            4       1.00      0.97      0.98        32
#            5       0.93      1.00      0.96        26
#            6       1.00      0.97      0.98        29
#
#     accuracy                           0.96       190
#    macro avg       0.96      0.96      0.96       190
# weighted avg       0.96      0.96      0.96       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        25
#            1       0.96      1.00      0.98        25
#            2       0.93      1.00      0.96        27
#            3       1.00      0.92      0.96        26
#            4       1.00      1.00      1.00        32
#            5       1.00      1.00      1.00        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.98       190
#    macro avg       0.98      0.98      0.98       190
# weighted avg       0.99      0.98      0.98       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       0.96      0.92      0.94        25
#            2       0.79      0.85      0.82        27
#            3       0.88      0.81      0.84        26
#            4       0.97      1.00      0.98        32
#            5       1.00      0.96      0.98        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.94       190
#    macro avg       0.94      0.93      0.94       190
# weighted avg       0.94      0.94      0.94       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        24
#            1       0.93      1.00      0.96        26
#            2       1.00      0.93      0.96        27
#            3       1.00      1.00      1.00        26
#            4       1.00      0.97      0.98        32
#            5       0.96      1.00      0.98        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.98       190
#    macro avg       0.98      0.98      0.98       190
# weighted avg       0.99      0.98      0.98       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        24
#            1       1.00      0.96      0.98        26
#            2       0.96      1.00      0.98        27
#            3       1.00      0.96      0.98        26
#            4       1.00      1.00      1.00        32
#            5       1.00      1.00      1.00        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.99       190
#    macro avg       0.99      0.99      0.99       190
# weighted avg       0.99      0.99      0.99       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        24
#            1       0.93      1.00      0.96        26
#            2       0.96      0.85      0.90        27
#            3       0.86      0.92      0.89        26
#            4       0.97      0.94      0.95        32
#            5       0.96      1.00      0.98        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.95       190
#    macro avg       0.95      0.95      0.95       190
# weighted avg       0.95      0.95      0.95       190
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        24
#            1       1.00      0.92      0.96        26
#            2       0.93      0.96      0.95        27
#            3       0.96      1.00      0.98        26
#            4       1.00      0.97      0.98        32
#            5       0.96      0.96      0.96        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.97       190
#    macro avg       0.97      0.97      0.97       190
# weighted avg       0.97      0.97      0.97       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       1.00      0.92      0.96        26
#            2       0.89      0.96      0.93        26
#            3       0.96      0.93      0.94        27
#            4       1.00      1.00      1.00        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.97       190
#    macro avg       0.97      0.97      0.97       190
# weighted avg       0.97      0.97      0.97       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       1.00      0.92      0.96        26
#            2       0.96      0.96      0.96        26
#            3       0.96      1.00      0.98        27
#            4       1.00      1.00      1.00        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.98       190
#    macro avg       0.98      0.98      0.98       190
# weighted avg       0.98      0.98      0.98       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       1.00      0.92      0.96        25
#            2       0.92      0.92      0.92        26
#            3       0.93      0.96      0.95        27
#            4       1.00      1.00      1.00        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.97       189
#    macro avg       0.97      0.97      0.97       189
# weighted avg       0.97      0.97      0.97       189
#
# List of possible accuracy: [0.9631578947368421, 0.9842105263157894, 0.9368421052631579, 0.9842105263157894, 0.9894736842105263, 0.9526315789473684, 0.9736842105263158, 0.9736842105263158, 0.9842105263157894, 0.9735449735449735]
#
# Maximum Accuracy That can be obtained from this model is: 98.94736842105263 %
#
# Minimum Accuracy: 93.6842105263158 %
#
# Overall Accuracy: 97.15650236702868 %
#
# Standard Deviation: 1.5646675844642133 %

# %%
nb2 = GaussianNB(var_smoothing=0.001)
stratified_kfold_evaluation(skf, nb2, x_full_select, y_full_select)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.92      0.81        25
#            1       0.80      0.32      0.46        25
#            2       0.50      0.22      0.31        27
#            3       0.58      0.27      0.37        26
#            4       0.40      0.69      0.51        32
#            5       0.61      0.96      0.75        26
#            6       1.00      0.97      0.98        29
#
#     accuracy                           0.63       190
#    macro avg       0.66      0.62      0.60       190
# weighted avg       0.65      0.63      0.60       190
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.96      0.79        25
#            1       0.50      0.32      0.39        25
#            2       0.69      0.33      0.45        27
#            3       0.56      0.19      0.29        26
#            4       0.38      0.50      0.43        32
#            5       0.57      0.96      0.71        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.61       190
#    macro avg       0.62      0.61      0.58       190
# weighted avg       0.62      0.61      0.58       190
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.96      0.86        25
#            1       0.52      0.44      0.48        25
#            2       0.31      0.19      0.23        27
#            3       0.42      0.19      0.26        26
#            4       0.42      0.44      0.43        32
#            5       0.54      0.96      0.69        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.59       190
#    macro avg       0.57      0.60      0.56       190
# weighted avg       0.56      0.59      0.56       190
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.79      0.68        24
#            1       0.60      0.46      0.52        26
#            2       0.64      0.26      0.37        27
#            3       0.14      0.04      0.06        26
#            4       0.33      0.44      0.38        32
#            5       0.53      0.96      0.68        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.56       190
#    macro avg       0.54      0.56      0.52       190
# weighted avg       0.54      0.56      0.52       190
#
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83        24
#            1       0.79      0.42      0.55        26
#            2       0.79      0.41      0.54        27
#            3       0.38      0.12      0.18        26
#            4       0.38      0.44      0.41        32
#            5       0.41      0.85      0.55        27
#            6       1.00      0.96      0.98        28
#
#     accuracy                           0.59       190
#    macro avg       0.63      0.60      0.58       190
# weighted avg       0.63      0.59      0.57       190
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.88      0.76        24
#            1       0.60      0.46      0.52        26
#            2       0.67      0.37      0.48        27
#            3       0.67      0.08      0.14        26
#            4       0.33      0.41      0.37        32
#            5       0.48      0.96      0.64        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.59       190
#    macro avg       0.63      0.59      0.56       190
# weighted avg       0.63      0.59      0.55       190
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        24
#            1       0.65      0.58      0.61        26
#            2       0.35      0.22      0.27        27
#            3       0.17      0.04      0.06        26
#            4       0.40      0.62      0.49        32
#            5       0.59      0.89      0.71        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.61       190
#    macro avg       0.57      0.60      0.57       190
# weighted avg       0.57      0.61      0.57       190
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.76      0.70        25
#            1       0.52      0.54      0.53        26
#            2       0.33      0.12      0.17        26
#            3       1.00      0.11      0.20        27
#            4       0.38      0.58      0.46        31
#            5       0.58      1.00      0.73        26
#            6       0.97      1.00      0.98        29
#
#     accuracy                           0.59       190
#    macro avg       0.63      0.59      0.54       190
# weighted avg       0.63      0.59      0.54       190
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83        25
#            1       0.42      0.31      0.36        26
#            2       0.45      0.35      0.39        26
#            3       0.50      0.26      0.34        27
#            4       0.34      0.39      0.36        31
#            5       0.55      0.92      0.69        26
#            6       0.97      1.00      0.98        29
#
#     accuracy                           0.58       190
#    macro avg       0.57      0.59      0.56       190
# weighted avg       0.57      0.58      0.56       190
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.92      0.81        25
#            1       0.55      0.44      0.49        25
#            2       0.65      0.42      0.51        26
#            3       0.62      0.19      0.29        27
#            4       0.48      0.52      0.50        31
#            5       0.49      0.92      0.64        26
#            6       0.97      1.00      0.98        29
#
#     accuracy                           0.63       189
#    macro avg       0.64      0.63      0.60       189
# weighted avg       0.64      0.63      0.60       189
#
# List of possible accuracy: [0.6263157894736842, 0.6105263157894737, 0.5947368421052631, 0.5631578947368421, 0.5947368421052631, 0.5894736842105263, 0.6052631578947368, 0.5894736842105263, 0.5842105263157895, 0.6296296296296297]
#
# Maximum Accuracy That can be obtained from this model is: 62.96296296296296 %
#
# Minimum Accuracy: 56.315789473684205 %
#
# Overall Accuracy: 59.875243664717345 %
#
# Standard Deviation: 1.89130437773487 %

# %%
svm2 = SVC(kernel='linear')
stratified_kfold_evaluation(skf, svm2, x_full_select, y_full_select)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.96      0.87        25
#            1       0.85      0.44      0.58        25
#            2       0.73      0.59      0.65        27
#            3       0.57      0.77      0.66        26
#            4       0.85      0.88      0.86        32
#            5       0.90      1.00      0.95        26
#            6       1.00      0.97      0.98        29
#
#     accuracy                           0.81       190
#    macro avg       0.81      0.80      0.79       190
# weighted avg       0.82      0.81      0.80       190
#
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88        25
#            1       0.72      0.52      0.60        25
#            2       0.82      0.67      0.73        27
#            3       0.68      0.73      0.70        26
#            4       0.88      0.91      0.89        32
#            5       0.93      1.00      0.96        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.84       190
#    macro avg       0.83      0.83      0.83       190
# weighted avg       0.83      0.84      0.83       190
#
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        25
#            1       0.76      0.64      0.70        25
#            2       0.61      0.70      0.66        27
#            3       0.65      0.58      0.61        26
#            4       0.85      0.69      0.76        32
#            5       0.82      1.00      0.90        27
#            6       0.97      1.00      0.98        28
#
#     accuracy                           0.80       190
#    macro avg       0.80      0.80      0.80       190
# weighted avg       0.80      0.80      0.80       190
#
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        24
#            1       0.78      0.54      0.64        26
#            2       0.65      0.56      0.60        27
#            3       0.62      0.77      0.69        26
#            4       0.94      0.91      0.92        32
#            5       0.93      1.00      0.96        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.83       190
#    macro avg       0.82      0.82      0.82       190
# weighted avg       0.83      0.83      0.82       190
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.96      0.81        24
#            1       0.80      0.46      0.59        26
#            2       0.83      0.93      0.88        27
#            3       0.81      0.85      0.83        26
#            4       0.90      0.81      0.85        32
#            5       0.90      0.96      0.93        27
#            6       1.00      0.96      0.98        28
#
#     accuracy                           0.85       190
#    macro avg       0.85      0.85      0.84       190
# weighted avg       0.85      0.85      0.84       190
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.96      0.81        24
#            1       0.69      0.42      0.52        26
#            2       0.70      0.70      0.70        27
#            3       0.67      0.77      0.71        26
#            4       0.87      0.62      0.73        32
#            5       0.76      0.93      0.83        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.77       190
#    macro avg       0.77      0.77      0.76       190
# weighted avg       0.77      0.77      0.76       190
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        24
#            1       0.82      0.54      0.65        26
#            2       0.56      0.67      0.61        27
#            3       0.61      0.73      0.67        26
#            4       0.93      0.88      0.90        32
#            5       0.93      0.96      0.95        27
#            6       1.00      1.00      1.00        28
#
#     accuracy                           0.82       190
#    macro avg       0.83      0.82      0.82       190
# weighted avg       0.83      0.82      0.82       190
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89        25
#            1       0.68      0.50      0.58        26
#            2       0.58      0.73      0.64        26
#            3       0.77      0.63      0.69        27
#            4       0.90      0.87      0.89        31
#            5       0.93      1.00      0.96        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.82       190
#    macro avg       0.81      0.81      0.81       190
# weighted avg       0.82      0.82      0.81       190
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92        25
#            1       0.83      0.58      0.68        26
#            2       0.77      0.77      0.77        26
#            3       0.69      0.93      0.79        27
#            4       0.96      0.87      0.92        31
#            5       1.00      1.00      1.00        26
#            6       1.00      1.00      1.00        29
#
#     accuracy                           0.87       190
#    macro avg       0.88      0.87      0.87       190
# weighted avg       0.88      0.87      0.87       190
#
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85        25
#            1       0.79      0.44      0.56        25
#            2       0.73      0.85      0.79        26
#            3       0.80      0.74      0.77        27
#            4       0.93      0.81      0.86        31
#            5       0.90      1.00      0.95        26
#            6       0.97      1.00      0.98        29
#
#     accuracy                           0.84       189
#    macro avg       0.83      0.83      0.82       189
# weighted avg       0.84      0.84      0.83       189
#
# List of possible accuracy: [0.8052631578947368, 0.8368421052631579, 0.8, 0.8263157894736842, 0.8473684210526315, 0.7684210526315789, 0.8210526315789474, 0.8157894736842105, 0.8736842105263158, 0.8359788359788359]
#
# Maximum Accuracy That can be obtained from this model is: 87.36842105263159 %
#
# Minimum Accuracy: 76.84210526315789 %
#
# Overall Accuracy: 82.307156780841 %
#
# Standard Deviation: 2.7224891993004903 %

# %% [markdown]
# # 8. Metrics with Test Data

# %%
x_test.shape
# Out:
# (212, 16)

# %%
y_test.shape
# Out:
# (212,)

# %% [markdown]
# ## 8.1 K-Nearest Neighbors

# %%
knn = knn.fit(x_full, y_full)

res_knn = knn.predict(x_test)

print(classification_report(y_test, res_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.73      0.62        26
#            1       0.67      0.32      0.43        31
#            2       0.57      0.57      0.57        23
#            3       0.73      0.59      0.65        27
#            4       0.63      0.76      0.69        34
#            5       0.83      0.94      0.88        31
#            6       0.98      1.00      0.99        40
#
#     accuracy                           0.72       212
#    macro avg       0.71      0.70      0.69       212
# weighted avg       0.72      0.72      0.71       212

# %%
confusion_matrix = pd.crosstab(y_test, res_knn, rownames=['Atual'], colnames=['Predição'])
sns.heatmap(confusion_matrix, annot=True, fmt='d');

# %%
y_pred_proba_knn = knn.predict_proba(x_test)
skplt.metrics.plot_roc(y_test, y_pred_proba_knn);
plt.title('ROC Curves for K-Nearest Neighbors');

# %%
knn2 = knn2.fit(x_full, y_full)

res_knn2 = knn2.predict(x_test)

print(classification_report(y_test, res_knn2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.88      0.81        26
#            1       0.78      0.68      0.72        31
#            2       0.83      0.87      0.85        23
#            3       0.88      0.78      0.82        27
#            4       0.86      0.91      0.89        34
#            5       0.97      0.94      0.95        31
#            6       1.00      1.00      1.00        40
#
#     accuracy                           0.87       212
#    macro avg       0.87      0.87      0.86       212
# weighted avg       0.87      0.87      0.87       212

# %%
confusion_matrix = pd.crosstab(y_test, res_knn2, rownames=['Atual'], colnames=['Predição'])
sns.heatmap(confusion_matrix, annot=True, fmt='d');

# %%
y_pred_proba_knn2 = knn2.predict_proba(x_test)
skplt.metrics.plot_roc(y_test, y_pred_proba_knn2);
plt.title('ROC Curves for K-Nearest Neighbors');

# %% [markdown]
# ## 8.2 Decision Tree

# %%
dt = dt.fit(x_full, y_full)

res_dt = dt.predict(x_test)

print(classification_report(y_test, res_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        26
#            1       0.94      0.94      0.94        31
#            2       0.91      0.91      0.91        23
#            3       0.89      0.93      0.91        27
#            4       0.89      0.91      0.90        34
#            5       0.93      0.90      0.92        31
#            6       1.00      1.00      1.00        40
#
#     accuracy                           0.94       212
#    macro avg       0.94      0.94      0.94       212
# weighted avg       0.94      0.94      0.94       212

# %%
confusion_matrix = pd.crosstab(y_test, res_dt, rownames=['Atual'], colnames=['Predição'])
sns.heatmap(confusion_matrix, annot=True, fmt='d');

# %%
y_pred_proba_dt = dt.predict_proba(x_test)
skplt.metrics.plot_roc(y_test, y_pred_proba_dt);
plt.title('ROC Curves for Decision Tree');

# %%
dt2 = dt2.fit(x_full, y_full)

res_dt2 = dt2.predict(x_test)

print(classification_report(y_test, res_dt2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        26
#            1       0.94      0.97      0.95        31
#            2       0.85      0.96      0.90        23
#            3       0.96      0.85      0.90        27
#            4       0.94      0.94      0.94        34
#            5       0.94      0.97      0.95        31
#            6       1.00      1.00      1.00        40
#
#     accuracy                           0.95       212
#    macro avg       0.95      0.94      0.94       212
# weighted avg       0.95      0.95      0.95       212

# %%
confusion_matrix = pd.crosstab(y_test, res_dt2, rownames=['Atual'], colnames=['Predição'])
sns.heatmap(confusion_matrix, annot=True, fmt='d');

# %%
y_pred_proba_dt2 = dt2.predict_proba(x_test)
skplt.metrics.plot_roc(y_test, y_pred_proba_dt2);
plt.title('ROC Curves for ');

# %% [markdown]
# ## 8.3 Random Forest

# %%
rf = rf.fit(x_full, y_full)

res_rf = rf.predict(x_test)

print(classification_report(y_test, res_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        26
#            1       0.86      0.97      0.91        31
#            2       0.95      0.91      0.93        23
#            3       0.96      0.96      0.96        27
#            4       0.94      0.94      0.94        34
#            5       0.97      0.94      0.95        31
#            6       1.00      1.00      1.00        40
#
#     accuracy                           0.95       212
#    macro avg       0.95      0.95      0.95       212
# weighted avg       0.96      0.95      0.95       212

# %%
confusion_matrix = pd.crosstab(y_test, res_rf, rownames=['Atual'], colnames=['Predição'])
sns.heatmap(confusion_matrix, annot=True, fmt='d');

# %%
y_pred_proba_rf = rf.predict_proba(x_test)
skplt.metrics.plot_roc(y_test, y_pred_proba_rf);
plt.title('ROC Curves for Random Forest');

# %% [markdown]
# ## 8.4 Multilayer Perceptron

# %%
mlp = mlp.fit(x_full, y_full)

res_mlp = mlp.predict(x_test)

print(classification_report(y_test, res_mlp))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94        26
#            1       0.91      0.97      0.94        31
#            2       0.88      0.96      0.92        23
#            3       0.96      0.93      0.94        27
#            4       0.94      1.00      0.97        34
#            5       1.00      0.94      0.97        31
#            6       1.00      1.00      1.00        40
#
#     accuracy                           0.96       212
#    macro avg       0.96      0.95      0.95       212
# weighted avg       0.96      0.96      0.96       212

# %%
confusion_matrix = pd.crosstab(y_test, res_mlp, rownames=['Atual'], colnames=['Predição'])
sns.heatmap(confusion_matrix, annot=True, fmt='d');

# %%
y_pred_proba_mlp = mlp.predict_proba(x_test)
skplt.metrics.plot_roc(y_test, y_pred_proba_mlp);
plt.title('ROC Curves for Multilayer Perceptron');

# %%
mlp2 = mlp2.fit(x_full, y_full)

res_mlp2 = mlp2.predict(x_test)

print(classification_report(y_test, res_mlp2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        26
#            1       0.94      0.97      0.95        31
#            2       0.95      0.87      0.91        23
#            3       0.93      0.96      0.95        27
#            4       0.97      0.97      0.97        34
#            5       1.00      0.94      0.97        31
#            6       0.95      1.00      0.98        40
#
#     accuracy                           0.96       212
#    macro avg       0.96      0.95      0.95       212
# weighted avg       0.96      0.96      0.96       212

# %%
confusion_matrix = pd.crosstab(y_test, res_mlp2, rownames=['Atual'], colnames=['Predição'])
sns.heatmap(confusion_matrix, annot=True, fmt='d');

# %%
y_pred_proba_mlp2 = mlp2.predict_proba(x_test)
skplt.metrics.plot_roc(y_test, y_pred_proba_mlp2);
plt.title('ROC Curves for Multilayer Perceptron');

# %% [markdown]
# ## 8.5 Naive-Bayes

# %%
nb = nb.fit(x_full, y_full)

res_nb = nb.predict(x_test)

print(classification_report(y_test, res_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.88      0.75        26
#            1       0.50      0.35      0.42        31
#            2       0.47      0.30      0.37        23
#            3       0.67      0.22      0.33        27
#            4       0.39      0.35      0.37        34
#            5       0.48      0.94      0.64        31
#            6       1.00      1.00      1.00        40
#
#     accuracy                           0.60       212
#    macro avg       0.59      0.58      0.55       212
# weighted avg       0.61      0.60      0.58       212

# %%
confusion_matrix = pd.crosstab(y_test, res_nb, rownames=['Atual'], colnames=['Predição'])
sns.heatmap(confusion_matrix, annot=True, fmt='d');

# %%
y_pred_proba_nb = nb.predict_proba(x_test)
skplt.metrics.plot_roc(y_test, y_pred_proba_nb);
plt.title('ROC Curves for Naive Bayes');

# %%
nb2 = nb2.fit(x_full, y_full)

res_nb2 = nb2.predict(x_test)

print(classification_report(y_test, res_nb2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.88      0.72        26
#            1       0.58      0.35      0.44        31
#            2       0.47      0.30      0.37        23
#            3       0.67      0.22      0.33        27
#            4       0.37      0.47      0.42        34
#            5       0.58      0.90      0.71        31
#            6       1.00      1.00      1.00        40
#
#     accuracy                           0.62       212
#    macro avg       0.61      0.59      0.57       212
# weighted avg       0.63      0.62      0.59       212

# %%
confusion_matrix = pd.crosstab(y_test, res_nb2, rownames=['Atual'], colnames=['Predição'])
sns.heatmap(confusion_matrix, annot=True, fmt='d');

# %%
y_pred_proba_nb2 = nb2.predict_proba(x_test)
skplt.metrics.plot_roc(y_test, y_pred_proba_nb2);
plt.title('ROC Curves for Naive Bayes');

# %% [markdown]
# ## 8.6 Support Vector Machine

# %%
svm = SVC(probability=True)
svm2 = SVC(C=1, kernel='linear', probability=True)

# %%
svm = svm.fit(x_full, y_full)

res_svm = svm.predict(x_test)

print(classification_report(y_test, res_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.85      0.79        26
#            1       0.62      0.52      0.56        31
#            2       0.62      0.65      0.64        23
#            3       0.82      0.67      0.73        27
#            4       0.69      0.74      0.71        34
#            5       0.85      0.94      0.89        31
#            6       1.00      1.00      1.00        40
#
#     accuracy                           0.78       212
#    macro avg       0.76      0.76      0.76       212
# weighted avg       0.78      0.78      0.77       212

# %%
confusion_matrix = pd.crosstab(y_test, res_svm, rownames=['Atual'], colnames=['Predição'])
sns.heatmap(confusion_matrix, annot=True, fmt='d');

# %%
y_pred_proba_svm = svm.predict_proba(x_test)
skplt.metrics.plot_roc(y_test, y_pred_proba_svm);
plt.title('ROC Curves for Support Vector Machine');

# %%
svm2 = svm2.fit(x_full, y_full)

res_svm2 = svm2.predict(x_test)

print(classification_report(y_test, res_svm2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.96      0.85        26
#            1       0.83      0.65      0.73        31
#            2       0.77      0.74      0.76        23
#            3       0.75      0.78      0.76        27
#            4       0.87      0.79      0.83        34
#            5       0.85      0.94      0.89        31
#            6       1.00      1.00      1.00        40
#
#     accuracy                           0.84       212
#    macro avg       0.83      0.84      0.83       212
# weighted avg       0.85      0.84      0.84       212

# %%
confusion_matrix = pd.crosstab(y_test, res_svm2, rownames=['Atual'], colnames=['Predição'])
sns.heatmap(confusion_matrix, annot=True, fmt='d');

# %%
y_pred_proba_svm2 = svm2.predict_proba(x_test)
skplt.metrics.plot_roc(y_test, y_pred_proba_svm2);
plt.title('ROC Curves for Support Vector Machine');

# %%
# AUC & ROC Curve

# %%
# y_pred_proba = knn_best.predict_proba(X_val)

# visualizer = ROCAUC(knn_best, encoder={     0 : 'Insufficient_Weight', 
#                                             1 : 'Normal_Weight', 
#                                             2 : 'Overweight_Level_I', 
#                                             3 : 'Overweight_Level_II', 
#                                             4 : 'Obesity_Type_I', 
#                                             5 : 'Obesity_Type_II', 
#                                             6 : 'Obesity_Type_III'})
    
# visualizer.fit(X_train, y_train)
# visualizer.score(X_val, y_val)
# visualizer.show()

# %%
# y_pred_proba = tree_best.predict_proba(X_val)

# visualizer = ROCAUC(tree_best, encoder={     0 : 'Insufficient_Weight', 
#                                             1 : 'Normal_Weight', 
#                                             2 : 'Overweight_Level_I', 
#                                             3 : 'Overweight_Level_II', 
#                                             4 : 'Obesity_Type_I', 
#                                             5 : 'Obesity_Type_II', 
#                                             6 : 'Obesity_Type_III'})
    
# visualizer.fit(X_train, y_train)
# visualizer.score(X_val, y_val)
# visualizer.show()

# %%
# y_pred_proba_knn = knn2.predict_proba(x_test)

# # roc curve for classes
# fpr = {}
# tpr = {}
# thresh ={}

# n_class = 7

# for i in range(n_class):    
#     fpr[i], tpr[i], thresh[i] = roc_curve(y_test, y_pred_proba_knn[:,i], pos_label=i)
    
# # plotting    
# plt.plot(fpr[0], tpr[0], linestyle='--',color='orange', label='Class 0 vs Rest')
# plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label='Class 1 vs Rest')
# plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label='Class 2 vs Rest')
# plt.plot(fpr[3], tpr[3], linestyle='--',color='gray', label='Class 3 vs Rest')
# plt.plot(fpr[4], tpr[4], linestyle='--',color='red', label='Class 4 vs Rest')
# plt.plot(fpr[5], tpr[5], linestyle='--',color='purple', label='Class 5 vs Rest')
# plt.plot(fpr[6], tpr[6], linestyle='--',color='green', label='Class 6 vs Rest')
# plt.title('Multiclass ROC curve')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive rate')
# plt.legend(loc='best')
# #plt.savefig('Multiclass ROC',dpi=300);

# %%
#roc_auc_score(y_test, y_pred_proba_dt, multi_class='ovr' )
